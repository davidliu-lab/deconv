# %%
!~/deconv/scripts/csx_fractions_melanoma_insilico.sh
# Out:
# setting up CIBERSORTx in directory:
# /mnt/buckets/liulab/csx-runs/20210806_215938
# /mnt/buckets/liulab/csx-runs/20210806_215938/in ~/deconv
# ~/deconv
# /mnt/buckets/liulab/csx-runs/20210806_215938
# ├── [   0]  in
# │   ├── [ 27M]  mymixture.txt
# │   ├── [ 88M]  myrefsample.txt
# │   ├── [   0]  symlink-mymixture.txt -> /mnt/buckets/liulab/derek/simulations/experiments/cibersortx_sim_0.5sd.txt
# │   └── [   0]  symlink-myrefsample.txt -> /mnt/buckets/liulab/csx_example_files/Single_Cell_RNA-Seq_Melanoma_SuppFig_3b-d/scRNA-Seq_reference_melanoma_Tirosh_SuppFig_3b-d.txt
# └── [   0]  out
#
# 2 directories, 4 files
# >Running CIBERSORTxFractions...
# >[Options] username: lyronctk@stanford.edu
# >[Options] token: dfeba2c8b9d61daebee5fa87026b8e56
# >[Options] single_cell: TRUE
# >[Options] refsample: myrefsample.txt
# >[Options] mixture: mymixture.txt
# >[Options] replicates: 5
# >[Options] sampling: 0.5
# >[Options] fraction: 0.75
# >[Options] k.max: 999
# >[Options] q.value: 0.01
# >[Options] G.min: 300
# >[Options] G.max: 500
# >[Options] filter: FALSE
# >[Options] verbose: TRUE
# >[Options] QN: FALSE
# >Making reference sample file.
# >Making phenotype class file.
# >==========Signature Matrix Settings============
# >Pure samples file: /src/outdir//CIBERSORTx_myrefsample_inferred_refsample.txt
# >Phenotype classes file: /src/outdir//CIBERSORTx_myrefsample_inferred_phenoclasses.txt
# >Minimum number of DEGs to consider from each phenotype for signature matrix set to: 300
# >Maximum number of DEGs to consider from each phenotype for signature matrix set to: 500
# >Q-value for signature matrix construction set to: 0.01
# >Quantile normalization of input samples is disabled
# >===============================================
# >C++14
# >Loaded 40 columns and 23684 rows
# >=============Make Signature Matrix=============
# >Maximum condition number (kappa):999
# >71262 DEG expressed across 8 samples were identified
# >Group size: 495, Kappa: 14.9934287263485
# >Best kappa: 14.9934287263485
# >SVD UpperRightDiag: 54923.8
# >SVD LowerRightDiag: 3663.19
# >=============CIBERSORTx Settings===============
# >Mixture file: /src/data/mymixture.txt
# >Signature matrix file: /src/outdir//CIBERSORTx_myrefsample_inferred_phenoclasses.CIBERSORTx_myrefsample_inferred_refsample.bm.K999.txt
# >Enable verbose output
# >==================CIBERSORTx===================
# column Malignant Endothelial cells CAF T cells CD8 NK cells Macrophages T cells CD4 B cells P-value Correlation RMSE %Completed
# 1 0.726018 0.0120553 0.0409183 0.0278308 0.0222512 0.0392194 0.100657 1
# 2 0.91666 0 0.00248186 0.00157844 0.0103769 0.0139673 0.045217 2
# 3 0.310563 0.0589274 0.122819 0.0460923 0.0368715 0.0837204 0.275172 3
# 4 0.173783 0.0525621 0.217824 0.0464467 0.0616434 0.0866738 0.305837 4
# 5 0.308142 0.0592086 0.248322 0 0.0524021 0.051605 0.256415 5
# 6 0.442411 0.0213383 0.181818 0 0.0612594 0.0716153 0.177957 6
# 7 0.407424 0.0021202 0.0395015 0.0316327 0.0306459 0.0250475 0 7
# 8 0.0957009 0.0170901 0.142013 0.0317194 0.0622805 0.0807131 0.423273 8
# 9 0.30001 0.0811143 0.0507147 0.0339585 0.0448521 0.0764326 0.259106 9
# 10 0.598624 0.0542753 0.0591248 0.0176156 0.0151146 0.0267585 0.176176 10
# 11 0.914907 0.00944133 0.0232891 0 0.00639739 0.00611742 0.0367041 11
# 12 0.882309 0.00112692 0.00611692 0.0241191 0.00563434 0.0211604 0.0493255 12
# 13 0.727113 0 0.0382654 0.0682061 0.0350625 0.0300093 0.0822667 13
# 14 0.966052 0.000533349 0.00353694 0.00142222 0.00230702 0.00983154 0.014338 14
# 15 0.78564 0.00555928 0.0016999 0.048429 0.0273139 0.016066 0.0820388 15
# 16 0.36501 0.0736283 0.0221199 0.096978 0.141723 0.0795308 0.191009 16
# 17 0.556254 0.010013 0.0600284 0.0393447 0.0238746 0.0485683 0.193105 17
# 18 0.641631 0.00321551 0.0815456 0.0185639 0.0225161 0.0751609 0.138456 18
# 19 0.0127858 0.0713109 0.120931 0.0731619 0.0935633 0.136958 0.408047 19
# 20 0.772281 0 0.0743003 0 0.00940493 0.0270837 0.107959 20
# 21 0.347501 0.0112859 0.11697 0.0249063 0.0815781 0.103271 0.283661 21
# 22 0.124256 0.0882769 0.0955406 0.102924 0.114997 0.120783 0.275139 22
# 23 0.643104 0.00361993 0.0943661 0.0179237 0.00850384 0.0750992 0.108563 23
# 24 0.198576 0.0582072 0.113187 0.0763841 0.0612231 0.133313 0.303306 24
# 25 0.881396 0.0123103 0.00141561 0.000943686 0.010369 0.0227491 0.053548 25
# 26 0.770531 0.0168803 0.0204947 0.0207501 0.019269 0.0351205 0.0854885 26
# 27 0.601113 0.00640531 0.0713168 0.0249762 0.0262399 0.0628596 0.165665 27
# 28 0.597127 0.0141268 0.12821 0 0.0432655 0.0467322 0.162561 28
# 29 0.395936 0.109079 0.0642679 0.0439563 0.0363339 0.0946267 0.187729 29
# 30 0.528325 0.0383302 0.0949058 0 0.0578879 0.0796877 0.174716 30
# 31 0.325406 0.0253916 0.139992 0.16925 0.069147 0.0718708 0.170896 31
# 32 0.183535 0.0474513 0.0921257 0.143993 0.0898772 0.0581561 0.254113 32
# 33 0.620359 0.00334586 0.0212979 0.00808824 0.021466 0.206224 0.0816828 33
# 34 0.796977 0.0144973 0.0492282 0.0066953 0.00860606 0.0254051 0.0875063 34
# 35 0.835043 0.0338726 0.00703734 0 0.0101163 0.0334524 0.077159 35
# 36 0.948903 0.00103726 0.00348132 0.00869401 0.00601794 0.0104197 0.0188179 36
# 37 0.27676 0.0414145 0.138023 0.0760117 0.0466442 0.0508489 0.192815 37
# 38 0.13254 0.0250756 0.212093 0.0439452 0.0349009 0.0947504 0.387627 38
# 39 0.29449 0.0892724 0.0508939 0.0654984 0.0394294 0.102434 0.277609 39
# 40 0.510212 0.0198275 0.12391 0.0242877 0.0211514 0.0917352 0.187202 40
# 41 0.52643 0.00754727 0.11781 0.0367492 0.0188884 0.0480057 0.208686 41
# 42 0.2205 0.066931 0.0195228 0.00552896 0.0333961 0.100503 0.44055 42
# 43 0.845367 0.00134005 0.00127134 0.00990135 0.00886544 0.0332304 0.0961475 43
# 44 0.00434428 0.126042 0.155715 0.129893 0.0569758 0.0784172 0.314044 44
# 45 0.814676 0.00200529 0.0466744 0.00202562 0.010785 0.0214739 0.0990263 45
# 46 0.819414 0.00354299 0.0213938 0.0105322 0.00772979 0.0176593 0.0925139 46
# 47 0.115682 0.00395899 0.231196 0.0418993 0.0711787 0.114516 0.38409 47
# 48 0.475019 0.0107474 0.00506838 0.434739 0.0463449 0.0165483 0 48
# 49 0.700474 0.0119536 0.0356839 0.0360137 0.0272979 0.0494015 0.127182 49
# 50 0.63125 0.0183389 0.0548261 0.0613127 0.00618632 0.0709916 0.153764 50
# 51 0.746306 0.00442019 0.0292339 0.011586 0.0216291 0.0287435 0.124424 51
# 52 0.888036 0 0.00858476 0.010756 0.0155824 0.0244595 0.0320624 52
# 53 0.639146 0.0162381 0.01894 0.0316454 0.0348815 0.05436 0.193683 53
# 54 0.191588 0.0197607 0.181238 0.0746188 0.0353145 0.0989188 0.297024 54
# 55 0.299392 0.0254155 0.048749 0.02689 0.0232818 0.0870331 0.273138 55
# 56 0.599638 0.0339774 0.0449409 0 0.0202714 0.0565104 0.183267 56
# 57 0.462113 0.00510919 0.112797 0 0.0431218 0.060636 0.244031 57
# 58 0.113064 0.00515029 0.212991 0.0221117 0.122849 0.111985 0.321514 58
# 59 0.083112 0.0364956 0.204233 0.014745 0.0785617 0.116522 0.341483 59
# 60 0.488236 0.00891989 0.0966613 0 0.026755 0.0753001 0.230862 60
# 61 0.174467 0.0619355 0.142803 0.0131543 0.0351062 0.111427 0.342496 61
# 62 0.251251 0 0.126117 0.0583065 0.0141716 0.0739075 0.383568 62
# 63 0.0156332 0.0122832 0.133671 0.0810768 0.0767876 0.133059 0.435554 63
# 64 0.635696 0.0204927 0.0670233 0.0685578 0.0179509 0.0911306 0.0682779 64
# 65 0.359805 0.0163375 0.197536 0.0350276 0.0229401 0.0795929 0.205627 65
# 66 0.656285 0.00177999 0.0117147 0.0493856 0.0132611 0.0194522 0.238679 66
# 67 0.174696 0.0661959 0.175797 0.0542284 0.0432881 0.131676 0.234907 67
# 68 0.0894688 0.0497697 0.174434 0.0487357 0.0268602 0.0746467 0.406608 68
# 69 0.422961 0.0245229 0.107368 0.0343047 0.0278221 0.0502138 0.275146 69
# 70 0.389503 0.109458 0.0355897 0.0134203 0.0242176 0.0767861 0.287529 70
# 71 0.170196 0.043128 0.0561269 0.136835 0.0519749 0.136523 0.382179 71
# 72 0.137295 0.000817252 0.18363 0.0928344 0.053207 0.13559 0.34146 72
# 73 0.42429 0.0258494 0.0610219 0.115734 0.0505341 0.0802415 0.189619 73
# 74 0.49698 0.0272341 0.0334609 0.12578 0.0684695 0.0315889 0.179753 74
# 75 0.0190437 0.0524577 0.278964 0.0308226 0.0550892 0.0660464 0.39378 75
# 76 0.216364 0.0180401 0.21986 0.0289418 0.028745 0.10858 0.304942 76
# 77 0.711322 0.00482826 0.0557221 0.01447 0.0305001 0.0340616 0.137616 77
# 78 0.0296351 0.0888531 0.131419 0.212826 0.112735 0.0739494 0.24678 78
# 79 0.473863 0.0127376 0.0516165 0.0277951 0.0512567 0.0776825 0.235456 79
# 80 0.41804 0.0504386 0.0670405 0.183063 0.0395112 0.0769874 0.12343 80
# 81 0.376998 0.0926701 0.0270409 0 0.0467481 0.0836155 0.315527 81
# 82 0.791866 0.0115834 0.0328702 0.0256684 0.0100272 0.0307982 0.073402 82
# 83 0.38516 0.00527456 0.161039 0.0202982 0.0506507 0.0883705 0.245528 83
# 84 0.400906 0.0153523 0.000291613 0.0510283 0.0421343 0.0606455 0.334687 84
# 85 0.150504 0.00813607 0.153191 0.0441425 0.067168 0.131962 0.335678 85
# 86 0.772617 0.00213903 0.0287912 0.0221576 0.0131684 0.0271814 0.120327 86
# 87 0.0222585 0.0934821 0.220683 0.0996473 0.0788601 0.0848869 0.282511 87
# 88 0.00972656 0.0705319 0.209296 0.0387745 0.120822 0.144073 0.37681 88
# 89 0.877904 0.00210508 0.0163166 0.00116704 0.00604392 0.0262522 0.0678451 89
# 90 0.314886 0.0636705 0.179199 0 0.0395388 0.0468653 0.276341 90
# 91 0.367427 0.0292695 0.0960294 0.051081 0.0377059 0.123324 0.258335 91
# 92 0.419557 0.0482778 0.137143 0.0358482 0.019493 0.0770323 0.206773 92
# 93 0.11927 0.0450161 0.240637 0 0.106321 0.0527057 0.381165 93
# 94 0.374517 0.0516128 0.0502375 0.0664651 0.0460207 0.0844193 0.251389 94
# 95 0.0369696 0.0414581 0.0862127 0.0890715 0.0519253 0.104567 0.489201 95
# 96 0.661506 0.0487439 0 0.0607723 0.0526871 0.021791 0.105711 96
# 97 0.47148 0.0499259 0.0656909 0 0.0553068 0.0614637 0.21918 97
# 98 0.0364739 0 0.231196 0.151086 0.0398343 0.105194 0.302634 98
# 99 0.259788 0.0101759 0.146482 0.234255 0.100366 0.122076 0.0725247 99
# 100 0.319873 0.0812143 0.187493 0.0498093 0.0640208 0.0314127 0.153575 100
# /mnt/buckets/liulab/csx-runs/20210806_215938
# ├── [   0]  in
# │   ├── [ 27M]  mymixture.txt
# │   ├── [ 88M]  myrefsample.txt
# │   ├── [   0]  symlink-mymixture.txt -> /mnt/buckets/liulab/derek/simulations/experiments/cibersortx_sim_0.5sd.txt
# │   └── [   0]  symlink-myrefsample.txt -> /mnt/buckets/liulab/csx_example_files/Single_Cell_RNA-Seq_Melanoma_SuppFig_3b-d/scRNA-Seq_reference_melanoma_Tirosh_SuppFig_3b-d.txt
# └── [   0]  out
#     ├── [ 23K]  CIBERSORTx_Results.txt
#     ├── [3.8M]  CIBERSORTx_cell_type_sourceGEP.txt
#     ├── [172K]  CIBERSORTx_myrefsample_inferred_phenoclasses.CIBERSORTx_myrefsample_inferred_refsample.bm.K999.pdf
#     ├── [510K]  CIBERSORTx_myrefsample_inferred_phenoclasses.CIBERSORTx_myrefsample_inferred_refsample.bm.K999.txt
#     ├── [ 725]  CIBERSORTx_myrefsample_inferred_phenoclasses.txt
#     └── [ 18M]  CIBERSORTx_myrefsample_inferred_refsample.txt
#
# 2 directories, 10 files

# %%
import pandas as pd

# %% [markdown]
# # fractions predicted by csx

# %%
csx_fractions = pd.read_csv(
    "/mnt/buckets/liulab/csx-runs/20210806_215938/out/CIBERSORTx_Results.txt",
    sep="\t",
    index_col=0
).loc[:, "Malignant":"B cells"]

# %%
csx_fractions
# Out:
#                Malignant  Endothelial cells       CAF  T cells CD8  NK cells  \
# Mixture
# sim.tumor.1     0.726018           0.012055  0.040918     0.027831  0.022251
# sim.tumor.2     0.916660           0.000000  0.002482     0.001578  0.010377
# sim.tumor.3     0.310563           0.058927  0.122819     0.046092  0.036871
# sim.tumor.4     0.173783           0.052562  0.217824     0.046447  0.061643
# sim.tumor.5     0.308142           0.059209  0.248322     0.000000  0.052402
# ...                  ...                ...       ...          ...       ...
# sim.tumor.96    0.661506           0.048744  0.000000     0.060772  0.052687
# sim.tumor.97    0.471480           0.049926  0.065691     0.000000  0.055307
# sim.tumor.98    0.036474           0.000000  0.231196     0.151086  0.039834
# sim.tumor.99    0.259788           0.010176  0.146482     0.234255  0.100366
# sim.tumor.100   0.319873           0.081214  0.187493     0.049809  0.064021
#
#                Macrophages  T cells CD4   B cells
# Mixture
# sim.tumor.1       0.039219     0.100657  0.031050
# sim.tumor.2       0.013967     0.045217  0.009718
# sim.tumor.3       0.083720     0.275172  0.065834
# sim.tumor.4       0.086674     0.305837  0.055230
# sim.tumor.5       0.051605     0.256415  0.023904
# ...                    ...          ...       ...
# sim.tumor.96      0.021791     0.105711  0.048788
# sim.tumor.97      0.061464     0.219180  0.076953
# sim.tumor.98      0.105194     0.302634  0.133581
# sim.tumor.99      0.122076     0.072525  0.054333
# sim.tumor.100     0.031413     0.153575  0.112602
#
# [100 rows x 8 columns]

# %%
csx_fractions_derek = pd.read_csv(
    "/mnt/buckets/liulab/derek/simulations/experiments/cibersortx/cibersortx_sim_0.5sd/CIBERSORTxGEP_Job3_Fractions-Adjusted.txt",    sep="\t",
    index_col=0
).loc[:, "Malignant":"B cells"]
csx_fractions_derek
# Out:
#                Malignant  Endothelial cells       CAF  T cells CD8  NK cells  \
# Mixture
# sim.tumor.1     0.634537           0.009402  0.068497     0.013531  0.027027
# sim.tumor.2     0.843653           0.000547  0.012051     0.011933  0.013648
# sim.tumor.3     0.356872           0.037935  0.104678     0.042459  0.030138
# sim.tumor.4     0.243679           0.025083  0.190378     0.048065  0.048958
# sim.tumor.5     0.357577           0.044369  0.225275     0.000000  0.031734
# ...                  ...                ...       ...          ...       ...
# sim.tumor.96    0.570503           0.043110  0.005001     0.041151  0.047830
# sim.tumor.97    0.428931           0.037244  0.075210     0.023856  0.043723
# sim.tumor.98    0.096804           0.004556  0.179027     0.115687  0.037100
# sim.tumor.99    0.304915           0.006214  0.154668     0.191630  0.077133
# sim.tumor.100   0.357514           0.061474  0.146799     0.022189  0.064513
#
#                Macrophages  T cells CD4   B cells
# Mixture
# sim.tumor.1       0.055589     0.154121  0.037297
# sim.tumor.2       0.024833     0.066372  0.026962
# sim.tumor.3       0.095473     0.283333  0.049112
# sim.tumor.4       0.096852     0.304444  0.042541
# sim.tumor.5       0.087326     0.205566  0.048153
# ...                    ...          ...       ...
# sim.tumor.96      0.063391     0.154164  0.074852
# sim.tumor.97      0.077986     0.232984  0.080066
# sim.tumor.98      0.138810     0.310514  0.117502
# sim.tumor.99      0.116719     0.091014  0.057708
# sim.tumor.100     0.038568     0.198272  0.110671
#
# [100 rows x 8 columns]

# %% [markdown]
# # truth

# %%
truth = pd.read_csv(
    "/mnt/buckets/liulab/derek/simulations/experiments/generate_cohorts_for_emma/ctp_sim_0.5sd.txt",
    sep="\t"
)

# %%
truth
# Out:
#      Malignant.cell  Endothelial.cell       CAF     T.CD8        NK  \
# 1             0.725          0.030567  0.053134  0.014234  0.019605
# 2             0.207          0.088145  0.153220  0.041046  0.056533
# 3             0.566          0.048241  0.083856  0.022464  0.030940
# 4             0.841          0.017673  0.030721  0.008230  0.011335
# 5             0.683          0.035236  0.061250  0.016408  0.022599
# ..              ...               ...       ...       ...       ...
# 96            0.596          0.044906  0.078059  0.020911  0.028801
# 97            0.408          0.065803  0.114384  0.030642  0.042204
# 98            0.246          0.083810  0.145685  0.039027  0.053753
# 99            0.691          0.034346  0.059704  0.015994  0.022029
# 100           0.582          0.046462  0.080764  0.021636  0.029799
#
#      Macrophage     T.CD4    B.cell
# 1      0.025273  0.085953  0.046233
# 2      0.072878  0.247859  0.133320
# 3      0.039885  0.135650  0.072964
# 4      0.014612  0.049697  0.026731
# 5      0.029133  0.099081  0.053294
# ..          ...       ...       ...
# 96     0.037128  0.126273  0.067921
# 97     0.054406  0.185034  0.099528
# 98     0.069294  0.235669  0.126763
# 99     0.028398  0.096580  0.051949
# 100    0.038415  0.130649  0.070274
#
# [100 rows x 8 columns]

# %% [markdown]
# # plots of predictions vs truth

# %%
import plotly.io
plotly.io.renderers.default = "jupyterlab+png"

import plotly.express as px

# %% [markdown]
# ## my predictions (docker)

# %%
fig = px.scatter(
    x=truth.stack().values,
    y=csx_fractions.stack().values,
    color=csx_fractions.stack().reset_index()["level_1"]
)
fig.update_layout(
    width = 600,
    height = 500,
)
fig.update_xaxes(
    range=(0, 1)
)
fig.update_yaxes(
    range=(0, 1),
)

# %% [markdown]
# ## Derek's predictions (website)

# %%
fig = px.scatter(
    x=truth.stack().values,
    y=csx_fractions_derek.stack().values,
    color=csx_fractions_derek.stack().reset_index()["level_1"]
)
fig.update_layout(
    width = 600,
    height = 500,
)
fig.update_xaxes(
    range=(0, 1)
)
fig.update_yaxes(
    range=(0, 1),
)
