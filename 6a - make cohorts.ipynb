# %%
import importlib

import numpy as np
import pandas as pd

from helpers.creating_mixtures import make_mixtures, make_a_cell_type_gep_matrix
from helpers.loading_single_cell_cohorts import load_tirosh

# %%
import helpers
importlib.reload(helpers.creating_mixtures)
from helpers.creating_mixtures import make_mixtures, make_a_cell_type_gep_matrix
importlib.reload(helpers.loading_single_cell_cohorts)
from helpers.loading_single_cell_cohorts import load_tirosh

# %% [markdown]
# # load single cell data

# %%
sc_data, sc_metadata = load_tirosh()

# %%
sc_data
# Out:
# cells       cy78_CD45_neg_1_B04_S496_comb  \
# GeneSymbol
# C9orf152                         0.000000
# RPS11                            8.144184
# ELMO2                            2.639232
# CREB3L1                          0.000000
# PNMA1                            3.656496
# ...                                   ...
# PIK3IP1                          0.936591
# SNRPD2                           5.374866
# SLC39A6                          3.326681
# CTSC                             2.612352
# AQP7                             0.000000
#
# cells       cy79_p4_CD45_neg_PDL1_neg_E11_S1115_comb  CY88_5_B10_S694_comb  \
# GeneSymbol
# C9orf152                                    0.000000              0.000000
# RPS11                                       5.915091              7.243164
# ELMO2                                       0.000000              0.732052
# CREB3L1                                     0.000000              0.000000
# PNMA1                                       0.000000              0.536053
# ...                                              ...                   ...
# PIK3IP1                                     5.761498              0.000000
# SNRPD2                                      0.000000              5.437661
# SLC39A6                                     0.000000              1.308011
# CTSC                                        0.000000              2.361768
# AQP7                                        0.000000              0.000000
#
# cells       cy79_p1_CD45_neg_PDL1_pos_AS_C1_R1_F07_S67_comb  \
# GeneSymbol
# C9orf152                                           0.000000
# RPS11                                              6.019502
# ELMO2                                              3.687956
# CREB3L1                                            0.000000
# PNMA1                                              3.041418
# ...                                                     ...
# PIK3IP1                                            0.000000
# SNRPD2                                             6.240581
# SLC39A6                                            3.516141
# CTSC                                               1.094236
# AQP7                                               0.000000
#
# cells       cy78_CD45_neg_3_H06_S762_comb  \
# GeneSymbol
# C9orf152                         0.000000
# RPS11                            7.974753
# ELMO2                            2.599318
# CREB3L1                          0.000000
# PNMA1                            4.132741
# ...                                   ...
# PIK3IP1                          2.034216
# SNRPD2                           5.946754
# SLC39A6                          3.868390
# CTSC                             1.934705
# AQP7                             0.000000
#
# cells       cy79_p1_CD45_neg_PDL1_pos_AS_C1_R1_G01_S73_comb  \
# GeneSymbol
# C9orf152                                           0.000000
# RPS11                                              5.557257
# ELMO2                                              1.691087
# CREB3L1                                            0.000000
# PNMA1                                              2.827006
# ...                                                     ...
# PIK3IP1                                            0.000000
# SNRPD2                                             4.628132
# SLC39A6                                            1.791189
# CTSC                                               0.852798
# AQP7                                               0.000000
#
# cells       cy79_p1_CD45_neg_PDL1_neg_AS_C4_R1_D09_S141_comb  \
# GeneSymbol
# C9orf152                                            0.000000
# RPS11                                               4.639058
# ELMO2                                               2.019346
# CREB3L1                                             0.000000
# PNMA1                                               0.000000
# ...                                                      ...
# PIK3IP1                                             0.000000
# SNRPD2                                              4.648580
# SLC39A6                                             0.000000
# CTSC                                                0.532068
# AQP7                                                0.000000
#
# cells       CY88_3_D02_S614_comb  \
# GeneSymbol
# C9orf152                0.000000
# RPS11                   7.655502
# ELMO2                   0.136191
# CREB3L1                 0.000000
# PNMA1                   2.873420
# ...                          ...
# PIK3IP1                 0.000000
# SNRPD2                  4.330415
# SLC39A6                 2.948601
# CTSC                    1.904966
# AQP7                    0.000000
#
# cells       cy79_p1_CD45_neg_PDL1_neg_AS_C4_R1_D06_S138_comb  \
# GeneSymbol
# C9orf152                                            0.000000
# RPS11                                               3.554834
# ELMO2                                               0.000000
# CREB3L1                                             0.000000
# PNMA1                                               0.000000
# ...                                                      ...
# PIK3IP1                                             0.000000
# SNRPD2                                              4.559981
# SLC39A6                                             4.368279
# CTSC                                                0.999278
# AQP7                                                0.000000
#
# cells       cy53_1_CD45_neg_C06_S318_comb  ...  monika_C11_S119_comb_BCD8_3  \
# GeneSymbol                                 ...
# C9orf152                         0.000000  ...                     0.000000
# RPS11                            8.791371  ...                     8.116349
# ELMO2                            1.724650  ...                     1.580145
# CREB3L1                          0.000000  ...                     0.000000
# PNMA1                            4.787694  ...                     0.000000
# ...                                   ...  ...                          ...
# PIK3IP1                          0.000000  ...                     0.000000
# SNRPD2                           5.664966  ...                     5.350462
# SLC39A6                          0.000000  ...                     0.000000
# CTSC                             1.456806  ...                     1.851199
# AQP7                             0.000000  ...                     0.000000
#
# cells       CY75_1_CD45_CD8_8__S331_comb_BCD8  \
# GeneSymbol
# C9orf152                             0.000000
# RPS11                                5.756490
# ELMO2                                0.000000
# CREB3L1                              0.000000
# PNMA1                                1.407081
# ...                                       ...
# PIK3IP1                              0.000000
# SNRPD2                               0.000000
# SLC39A6                              4.774840
# CTSC                                 6.475069
# AQP7                                 0.000000
#
# cells       CY75_1_CD45_CD8_7__S210_comb_BCD8  \
# GeneSymbol
# C9orf152                             0.000000
# RPS11                                0.000000
# ELMO2                                1.075875
# CREB3L1                              0.000000
# PNMA1                                0.000000
# ...                                       ...
# PIK3IP1                              0.000000
# SNRPD2                               5.225853
# SLC39A6                              4.881518
# CTSC                                 3.449957
# AQP7                                 0.000000
#
# cells       CY75_1_CD45_CD8_3__S142_comb_BCD8  \
# GeneSymbol
# C9orf152                             0.000000
# RPS11                                5.258820
# ELMO2                                0.000000
# CREB3L1                              0.000000
# PNMA1                                0.000000
# ...                                       ...
# PIK3IP1                              0.000000
# SNRPD2                               3.966523
# SLC39A6                              5.688656
# CTSC                                 0.000000
# AQP7                                 0.000000
#
# cells       CY75_1_CD45_CD8_7__S280_comb_BCD8  \
# GeneSymbol
# C9orf152                             0.000000
# RPS11                                3.930454
# ELMO2                                5.616211
# CREB3L1                              0.000000
# PNMA1                                0.000000
# ...                                       ...
# PIK3IP1                              5.018011
# SNRPD2                               5.537203
# SLC39A6                              0.000000
# CTSC                                 0.145351
# AQP7                                 0.000000
#
# cells       CY75_1_CD45_CD8_3__S168_comb_BCD8  \
# GeneSymbol
# C9orf152                             0.000000
# RPS11                                5.945186
# ELMO2                                0.000000
# CREB3L1                              0.000000
# PNMA1                                0.000000
# ...                                       ...
# PIK3IP1                              0.000000
# SNRPD2                               6.792582
# SLC39A6                              0.000000
# CTSC                                 6.871634
# AQP7                                 0.000000
#
# cells       CY75_1_CD45_CD8_8__S338_comb_BCD8  monika_D7_S132_comb_BCD8_3  \
# GeneSymbol
# C9orf152                             0.000000                    0.000000
# RPS11                                6.661408                    6.792322
# ELMO2                                0.000000                    0.000000
# CREB3L1                              0.000000                    0.000000
# PNMA1                                0.000000                    0.000000
# ...                                       ...                         ...
# PIK3IP1                              1.491597                    0.000000
# SNRPD2                               0.000000                    0.000000
# SLC39A6                              0.000000                    0.000000
# CTSC                                 1.837540                    3.094236
# AQP7                                 0.000000                    0.000000
#
# cells       CY75_1_CD45_CD8_8__S289_comb_BCD8  \
# GeneSymbol
# C9orf152                             0.000000
# RPS11                                0.000000
# ELMO2                                0.000000
# CREB3L1                              0.000000
# PNMA1                                0.000000
# ...                                       ...
# PIK3IP1                              0.000000
# SNRPD2                               3.525944
# SLC39A6                              0.000000
# CTSC                                 6.253554
# AQP7                                 0.000000
#
# cells       CY75_1_CD45_CD8_8__S351_comb_BCD8
# GeneSymbol
# C9orf152                             0.000000
# RPS11                                4.820741
# ELMO2                                6.166655
# CREB3L1                              0.000000
# PNMA1                                0.000000
# ...                                       ...
# PIK3IP1                              4.510139
# SNRPD2                               6.218684
# SLC39A6                              0.000000
# CTSC                                 3.087463
# AQP7                                 0.000000
#
# [23686 rows x 7186 columns]

# %%
sc_metadata
# Out:
#                                                 cells samples cell.types  \
# 0                       cy78_CD45_neg_1_B04_S496_comb   Mel78  Malignant
# 1            cy79_p4_CD45_neg_PDL1_neg_E11_S1115_comb   Mel79  Malignant
# 2                                CY88_5_B10_S694_comb   Mel88  Malignant
# 3     cy79_p1_CD45_neg_PDL1_pos_AS_C1_R1_F07_S67_comb   Mel79  Malignant
# 4                       cy78_CD45_neg_3_H06_S762_comb   Mel78  Malignant
# ...                                               ...     ...        ...
# 7181                CY75_1_CD45_CD8_3__S168_comb_BCD8   Mel75      T CD8
# 7182                CY75_1_CD45_CD8_8__S338_comb_BCD8   Mel75      T CD8
# 7183                       monika_D7_S132_comb_BCD8_3   Mel75      T CD8
# 7184                CY75_1_CD45_CD8_8__S289_comb_BCD8   Mel75      T CD8
# 7185                CY75_1_CD45_CD8_8__S351_comb_BCD8   Mel75      T CD8
#
#       treatment.group  Cohort  no.of.genes  no.of.reads
# 0      post.treatment  Tirosh         8258       357919
# 1     treatment.naive  Tirosh         2047         5727
# 2      post.treatment  Tirosh         5375       139218
# 3     treatment.naive  Tirosh         5648        73996
# 4      post.treatment  Tirosh         7409       380341
# ...               ...     ...          ...          ...
# 7181   post.treatment  Tirosh         3530       137245
# 7182   post.treatment  Tirosh         3872       106432
# 7183   post.treatment  Tirosh         4589       908173
# 7184   post.treatment  Tirosh         4614       140903
# 7185   post.treatment  Tirosh         3859       222239
#
# [7186 rows x 7 columns]

# %% [markdown]
# # generate in silico mixtures

# %%
# params
n_samples = 100
n_cells_per_gep = 5
rng = np.random.default_rng(seed=0)

# %%
mixtures, fractions, cell_type_geps = \
    make_mixtures(sc_data, sc_metadata, n_samples, n_cells_per_gep, rng)

# %%
fractions
# Out:
#                    ?         B       CAF  Endothelial  Macrophage  Malignant  \
# Mixture
# sample_000  0.067716  0.000261  0.153100     0.059735    0.046277   0.155257
# sample_001  0.000250  0.156511  0.124144     0.166914    0.169037   0.005687
# sample_002  0.050285  0.016919  0.002314     0.281688    0.471453   0.037042
# sample_003  0.027906  0.012451  0.131887     0.060659    0.078164   0.127117
# sample_004  0.001353  0.219756  0.000022     0.469029    0.002266   0.161728
# ...              ...       ...       ...          ...         ...        ...
# sample_095  0.368399  0.108970  0.209961     0.041968    0.017304   0.014555
# sample_096  0.066298  0.525514  0.125977     0.005844    0.015760   0.001741
# sample_097  0.049189  0.063600  0.040889     0.064434    0.140273   0.265428
# sample_098  0.006416  0.325948  0.193502     0.005866    0.121915   0.045384
# sample_099  0.015459  0.001219  0.315969     0.070739    0.171860   0.066604
#
#                   NK         T     T CD4     T CD8
# Mixture
# sample_000  0.197522  0.101339  0.204832  0.013962
# sample_001  0.086222  0.073552  0.103814  0.113868
# sample_002  0.066496  0.017442  0.053661  0.002700
# sample_003  0.232561  0.087930  0.053780  0.187545
# sample_004  0.023590  0.094931  0.007252  0.020072
# ...              ...       ...       ...       ...
# sample_095  0.128538  0.002652  0.086253  0.021400
# sample_096  0.009656  0.163692  0.020579  0.064938
# sample_097  0.095713  0.073832  0.205691  0.000951
# sample_098  0.004266  0.093766  0.187834  0.015104
# sample_099  0.216493  0.033582  0.023539  0.084535
#
# [100 rows x 10 columns]

# %%
cell_type_geps["sample_000"]
# Out:
#                      ?           B        CAF  Endothelial  Macrophage  \
# GeneSymbol
# C9orf152      0.323727    0.000000   0.154548     0.000000    0.000000
# RPS11       110.933585  122.229508  77.017257    57.624794   47.158980
# ELMO2        20.648986    0.000000   4.549982     0.000000   16.402817
# CREB3L1       0.000000    0.000000  10.633207     0.000000    0.000000
# PNMA1         0.000000    0.000000   5.750597     0.000000    3.362768
# ...                ...         ...        ...          ...         ...
# PIK3IP1       0.000000   27.331386   6.672409    17.323806    1.461581
# SNRPD2       52.408093   64.876602  21.809404    29.948187   25.352713
# SLC39A6      19.762076    4.885528   2.637823     0.000000    4.871961
# CTSC         16.229633   15.282281  24.198817    22.639719   47.974547
# AQP7          0.000000    0.000000   0.000000     0.000000    0.000000
#
#             Malignant         NK          T      T CD4      T CD8
# GeneSymbol
# C9orf152     0.000000   0.000000   0.000000   0.000000   0.000000
# RPS11       58.202396  78.882148  84.193898  75.871714  75.296882
# ELMO2       10.226654   0.970098   0.000000   9.178976  13.080839
# CREB3L1      0.000000   0.000000   0.000000   0.000000   0.000000
# PNMA1        6.163958   0.000000   8.889885   0.000000  10.704404
# ...               ...        ...        ...        ...        ...
# PIK3IP1      0.000000   9.394013  23.875090  53.837218  27.795284
# SNRPD2      40.273131  19.368339  31.438779  29.435519  23.725973
# SLC39A6      4.903206  12.830691   6.810244   9.264079   3.055078
# CTSC        10.964457  21.937771  28.484870  37.874269  24.584043
# AQP7         0.000000   0.000000   0.000000   0.000000   0.000000
#
# [23686 rows x 10 columns]

# %%
mixtures
# Out:
#             sample_000  sample_001  sample_002  sample_003  sample_004  \
# GeneSymbol
# C9orf152      0.048722    0.267297    0.018928    0.000000    0.000003
# RPS11        77.028611   65.360772   62.671832   76.193165   60.259323
# ELMO2         7.299185    6.701818    1.270330    6.066638    5.748823
# CREB3L1       1.692915    1.432683    0.010597    0.798414    0.000000
# PNMA1         2.792134    2.920031    2.776262    3.688951    5.027202
# ...                ...         ...         ...         ...         ...
# PIK3IP1      16.805921   22.510577   14.780074   17.122102   27.536212
# SNRPD2       30.050135   32.511619   24.756727   33.759574   23.610539
# SLC39A6       8.546264    5.294142    2.343396    8.219684    7.830691
# CTSC         26.375810   33.220277   33.116891   36.246772   18.476197
# AQP7          0.000000    0.140842    0.000000    0.466483    0.000000
#
#             sample_005  sample_006  sample_007  sample_008  sample_009  ...  \
# GeneSymbol                                                              ...
# C9orf152      0.000046    0.210283    0.000000    0.000000    0.000000  ...
# RPS11        64.269863   72.133243   72.804058   70.240571   75.351059  ...
# ELMO2        12.481925    5.052713    8.961282    6.581195    8.060990  ...
# CREB3L1       2.165165    0.000000    0.127865    0.668248    0.000000  ...
# PNMA1         5.117519   10.727962    6.066179    6.493949    4.192655  ...
# ...                ...         ...         ...         ...         ...  ...
# PIK3IP1      23.567711   11.885759   29.322456   14.662794   17.376178  ...
# SNRPD2       27.257681   25.874738   38.856881   37.935240   29.383361  ...
# SLC39A6       6.896407   10.626049    5.560889    9.334241    1.848043  ...
# CTSC         36.455049   36.748397   32.652073   26.396852   29.781346  ...
# AQP7          0.000000    0.018013    0.018979    0.000000    0.000000  ...
#
#             sample_090  sample_091  sample_092  sample_093  sample_094  \
# GeneSymbol
# C9orf152      0.000000    0.000000    0.000000    0.000000    0.000801
# RPS11        77.260299   73.164672   83.657754   63.117997   78.278200
# ELMO2         5.823444    7.490615    3.053495   10.812111   11.103444
# CREB3L1       1.674022    2.700125    0.000000    0.422828    0.000000
# PNMA1         4.652189    1.280270    3.606490   12.066842    4.810473
# ...                ...         ...         ...         ...         ...
# PIK3IP1      28.156547   19.141073   13.832934   30.791788   29.992054
# SNRPD2       35.656352   28.702321   37.464356   17.854677   37.955080
# SLC39A6      12.854266    6.615601    5.680741    3.650169   12.022428
# CTSC         30.145669   34.115987   30.762365   31.920737   34.673791
# AQP7          0.036168    1.379443    0.000000    0.000194    0.000000
#
#             sample_095  sample_096  sample_097  sample_098  sample_099
# GeneSymbol
# C9orf152      0.000000    0.000000    1.039973    0.000000    0.047040
# RPS11        72.384505   93.000655   69.973881   80.158805   63.966535
# ELMO2         6.887148    7.920002    5.619630    1.248106    6.761255
# CREB3L1       0.000000    0.865062    0.320816    2.071884    1.393850
# PNMA1         2.952212    1.481002    3.204152    3.949565    3.236175
# ...                ...         ...         ...         ...         ...
# PIK3IP1      18.935636   12.234475   14.865665   42.988896   26.085630
# SNRPD2       19.597801   50.143831   32.303941   28.653381   30.865568
# SLC39A6       7.102989   10.084246   14.849752    8.474845    9.867918
# CTSC         24.769985   32.622040   33.323114   26.715486   27.245277
# AQP7          0.033150    0.351391    0.000000    0.000000    0.000000
#
# [23686 rows x 100 columns]

# %%
# desired...
# mixtures: pd.DataFrame(index=genes, columns=samples)
# fractions: pd.DataFrame(index=genes, columns=cell_types)
# cell_type_geps: pd.DataFrame(index=(sample, gene), columns=cell_types)

# %% [markdown]
# # output 1: estimated cell type fractions

# %%
from helpers.csx_docker import save_valid_mixture_file, save_valid_fractions_file

with open("mixture.txt", "w") as f:
    save_valid_mixture_file(mixtures, f)
with open("fractions.txt", "w") as f:
    save_valid_fractions_file(fractions, f)

# %%
run_csx(path='...')

# %% [markdown]
# # output 2: estimated gene expression by cell type
#
# ## volcano plot outputs

# %%
# for each cell type, scatter plot (effect_size, p_value) for each gene
