# %%
import pandas as pd

# %%
pd.read_excel("/mnt/buckets/liulab/pan-io_datasets/2019Oct_RNASeq_Census.xlsx", nrows=3)
# Out:
#                   participant                                  sample_id  \
# 0  BLADDER-15330_CCPM_0700627  BLADDER-15330_CCPM_0700627-Tumor-SM-AVI19
# 1  BLADDER-15330_CCPM_0700629  BLADDER-15330_CCPM_0700629-Tumor-SM-AVI1C
# 2  BLADDER-15330_CCPM_0700691  BLADDER-15330_CCPM_0700691-Tumor-SM-AVI13
#
#                                         fast_q1_file  \
# 0  BLADDER-15330_CCPM_0700627-Tumor-SM-AVI19_1.fa...
# 1  BLADDER-15330_CCPM_0700629-Tumor-SM-AVI1C_1.fa...
# 2  BLADDER-15330_CCPM_0700691-Tumor-SM-AVI13_1.fa...
#
#                                     fastq_name  \
# 0  BLADDER-15330_CCPM_0700627-Tumor-SM-AVI19_1
# 1  BLADDER-15330_CCPM_0700629-Tumor-SM-AVI1C_1
# 2  BLADDER-15330_CCPM_0700691-Tumor-SM-AVI13_1
#
#                              star_transcriptome_bams  \
# 0  gs://fc-dcb81cf3-cdf5-44ff-8ac0-88bf82428d5c/d...
# 1  gs://fc-dcb81cf3-cdf5-44ff-8ac0-88bf82428d5c/d...
# 2  gs://fc-dcb81cf3-cdf5-44ff-8ac0-88bf82428d5c/d...
#
# ...

# %%
pd.read_excel(
    "/mnt/buckets/liulab/pan-io_datasets/2020all_IO_pairs_census.xlsx", nrows=3
)
# Out:
#                                     pair_id  alt_pair_id       participant  \
# 0  AC-DFCI_AC_PD1-1-TP-NT-SM-9LRI9-SM-9LRIA          NaN  AC-DFCI_AC_PD1-1
# 1  AC-DFCI_AC_PD1-2-TP-NT-SM-9J4AO-SM-A4KOT          NaN  AC-DFCI_AC_PD1-2
# 2                                BL3403_T_N          NaN            BL3403
#
#                        case_sample                    control_sample  \
# 0  AC-DFCI_AC_PD1-1-Tumor-SM-9LRI9  AC-DFCI_AC_PD1-1-Normal-SM-9LRIA
# 1  AC-DFCI_AC_PD1-2-Tumor-SM-9J4AO  AC-DFCI_AC_PD1-2-Normal-SM-A4KOT
# 2                         BL3403_T                          BL3403_N
#
#       cohort disease  therapy bait_set treatment_context  ...  \
# 0  DFCI_misc    anal      NaN      ice      pretreatment  ...
# 1  DFCI_misc    anal      NaN      ice      pretreatment  ...
# 2      Rizvi    lung      NaN  agilent      pretreatment  ...
#
#   mutect1_basescovered normal_mean_target_coverage  \
# 0           40243628.0                  232.891179
# ...

# %%
pd.read_csv(
    "/mnt/buckets/liulab/pan-io_datasets/Clin_metadata_all (1).txt", sep="\t", nrows=3
)
# Out:
#          patient_id      cohort disease bait_set treatment_context  \
# 0  AC-DFCI_AC_PD1-1  DFCI misc.    anal      ice      pretreatment
# 1  AC-DFCI_AC_PD1-2  DFCI misc.    anal      ice      pretreatment
# 2            AU5884       Rizvi    lung  agilent      pretreatment
#
#   2018_nat_gen_published 2018_meta_dataset   age   sex       histology  ...  \
# 0                      Y                 Y   NaN  MALE             NaN  ...
# 1                      N     no_permission   NaN   NaN             NaN  ...
# 2                      Y         low_power  64.0  MALE  adenocarcinoma  ...
#
#           case_sample_pretreatment pair_id_ontreatment  \
# 0  AC-DFCI_AC_PD1-1-Tumor-SM-9LRI9                 NaN
# 1  AC-DFCI_AC_PD1-2-Tumor-SM-9J4AO                 NaN
# 2                         AU5884_T                 NaN
#
#    case_sample_ontreatment  pair_id_posttreatment case_sample_posttreatment  \
# 0                      NaN                    NaN                       NaN
# ...

# %%
pd.read_csv(
    "/mnt/buckets/liulab/pan-io_datasets/meta_seg_interpret.txt", sep="\t", nrows=3
)
# Out:
#                                     pair_id  chrom      start        end  \
# 0  AC-DFCI_AC_PD1-1-TP-NT-SM-9LRI9-SM-9LRIA      1      13100   23337700
# 1  AC-DFCI_AC_PD1-1-TP-NT-SM-9LRI9-SM-9LRIA      1   23340400  235973800
# 2  AC-DFCI_AC_PD1-1-TP-NT-SM-9LRI9-SM-9LRIA      1  235976124  249231200
#
#    ploidy  lesser_cn  greater_cn  total_cn  FACETS_seg  FACETS_nummark  ...  \
# 0    2.77          1           1         2           1            5313  ...
# 1    2.77          1           1         2           2           28039  ...
# 2    2.77          1           1         2           3            1560  ...
#
#    focality_a1  focality_a2  called_CNA1  called_CNA2  called_CNA_total  \
# 0     0.979583     0.979583          NaN          NaN               NaN
# 1     0.979583     0.979583          NaN          NaN               NaN
# 2     0.979583     0.979583          NaN          NaN               NaN
#
# ...

# %%
pd.read_csv(
    "/mnt/buckets/liulab/pan-io_datasets/panIO_master_maf_2020_plus_blat_filtered_muts.txt",
    sep="\t",
    nrows=3,
)
# Out:
#                                     pair_id   cohort.x   cohort.y Hugo_Symbol  \
# 0  AC-DFCI_AC_PD1-1-TP-NT-SM-9LRI9-SM-9LRIA  DFCI_misc  DFCI_misc     AADACL2
# 1  AC-DFCI_AC_PD1-1-TP-NT-SM-9LRI9-SM-9LRIA  DFCI_misc  DFCI_misc        AAK1
# 2  AC-DFCI_AC_PD1-1-TP-NT-SM-9LRI9-SM-9LRIA  DFCI_misc  DFCI_misc        ABAT
#
#    Chromosome  Start_position  End_position             Tumor_Sample_Barcode  \
# 0           3       151458542     151458542  AC-DFCI_AC_PD1-1-Tumor-SM-9LRI9
# 1           2        69741780      69741780  AC-DFCI_AC_PD1-1-Tumor-SM-9LRI9
# 2          16         8844285       8844285  AC-DFCI_AC_PD1-1-Tumor-SM-9LRI9
#
#         Matched_Norm_Sample_Barcode       participant  ...  realign_judgment  \
# 0  AC-DFCI_AC_PD1-1-Normal-SM-9LRIA  AC-DFCI_AC_PD1-1  ...               NaN
# 1  AC-DFCI_AC_PD1-1-Normal-SM-9LRIA  AC-DFCI_AC_PD1-1  ...               NaN
# 2  AC-DFCI_AC_PD1-1-Normal-SM-9LRIA  AC-DFCI_AC_PD1-1  ...               NaN
#
# ...

# %%
pd.read_csv(
    "/mnt/buckets/liulab/pan-io_datasets/TPM_matrix_rows.txt", sep="\t", nrows=3
)
# Out:
#                           X5S_rRNA  X7SK       A1BG  A1BG.AS1     A1CF  \
# 355154_L2.D712_1.clipped         0     0    20.4666   6.56674   0.0000
# 355157_L2.D702_1.clipped         0     0    58.1464   9.67952   0.0000
# 355158_L6_1.clipped              0     0  1416.6100   2.09020  12.3846
#
#                               A2M   A2M.AS1     A2ML1  A2ML1.AS1  A2ML1.AS2  \
# 355154_L2.D712_1.clipped  171.089  0.570306  0.022997          0          0
# 355157_L2.D702_1.clipped  369.830  1.978010  0.000000          0          0
# 355158_L6_1.clipped       690.528  0.613971  0.000000          0          0
#
#                           ...     ZWINT      ZXDA     ZXDB     ZXDC    ZYG11A  \
# 355154_L2.D712_1.clipped  ...  39.23120  1.499330  4.50453  9.13162  0.007177
# 355157_L2.D702_1.clipped  ...  36.30030  1.293410  4.86689  9.99290  0.055880
# 355158_L6_1.clipped       ...   3.49428  0.122899  2.69243  3.76213  0.145304
#
# ...
