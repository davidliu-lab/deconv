# %%
import os
import tempfile
import urllib

import pandas as pd

from helpers.cell_type_naming import nice_to_weirds, weird_to_nice

# %%
truth = (
    pd.read_csv(
        "gs://liulab/csx_example_files/groundtruth_Melanoma_Tirosh_et_al_SuppFig3b-d.txt",
        sep="\t",
        index_col=0,
    )
    .rename_axis(index="sample_id")
    .rename(columns=weird_to_nice)
)

truth
# Out:
#            Malignant  Endothelial     CAF   T CD8      NK  Macrophage   T CD4  \
# sample_id
# 53            0.1280       0.0880  0.0320  0.2000  0.0800      0.0960  0.3760
# 58            0.0000       0.0000  0.0000  0.6508  0.0317      0.0159  0.2857
# 59            0.8710       0.0000  0.1129  0.0000  0.0000      0.0161  0.0000
# 60            0.0448       0.0000  0.0000  0.1940  0.0498      0.0199  0.2139
# 65            0.0755       0.0000  0.0000  0.4717  0.0000      0.0189  0.3396
# 67            0.0000       0.0000  0.0000  0.3059  0.0118      0.0000  0.4588
# 71            0.6835       0.0000  0.0000  0.1899  0.0000      0.0253  0.1013
# 72            0.0000       0.0000  0.0000  0.1634  0.0065      0.0000  0.6013
# 74            0.0000       0.0000  0.0000  0.6496  0.0073      0.0365  0.2117
# 75            0.0087       0.0000  0.0000  0.9417  0.0000      0.0029  0.0466
# 78            0.9756       0.0000  0.0081  0.0000  0.0000      0.0000  0.0081
# 79            0.5474       0.0023  0.0012  0.2795  0.0012      0.0000  0.0760
# 80            0.2828       0.0656  0.0520  0.1538  0.0090      0.0000  0.3258
# 81            0.7308       0.0110  0.0000  0.1044  0.0000      0.0000  0.1374
# 82            0.4638       0.0000  0.0870  0.1304  0.0290      0.0580  0.2174
# 84            0.1045       0.0075  0.0075  0.1716  0.0522      0.1866  0.2836
# 88            0.3966       0.0000  0.0068  0.1559  0.0305      0.1356  0.2203
# 89            0.2263       0.0023  0.0000  0.3141  0.0023      0.0600  0.1501
# 94            0.0413       0.0785  0.0661  0.2025  0.0041      0.0083  0.3306
#
#                 B
# sample_id
# 53         0.0000
# 58         0.0159
# 59         0.0000
# 60         0.4776
# 65         0.0943
# 67         0.2235
# 71         0.0000
# 72         0.2288
# 74         0.0949
# 75         0.0000
# 78         0.0081
# 79         0.0924
# 80         0.1109
# 81         0.0165
# 82         0.0145
# 84         0.1866
# 88         0.0542
# 89         0.2448
# 94         0.2686

# %%
experiments_root = "liulab/csx_experiments/varying_parameters"

# !tree -h -L 1 {os.path.join("/mnt/buckets", experiments_root)}
# !tree -h -L 1 {os.path.join("/mnt/buckets", experiments_root, "defaults,single_cell_true")}
# Out:
# /mnt/buckets/liulab/csx_experiments/varying_parameters
# ├── [   0]  defaults
# ├── [   0]  refsample_from_defaults
# ├── [   0]  refsample_from_defaults,single_cell_true
# ├── [   0]  refsample_from_defaults,with_bmode
# ├── [   0]  refsample_from_webjob4
# ├── [   0]  refsample_from_webjob4,with_bmode
# ├── [   0]  sigmat_from_defaults
# ├── [   0]  sigmat_from_defaults,with_bmode
# ├── [   0]  sigmat_from_webjob4
# ├── [   0]  sigmat_from_webjob4,with_bmode
# └── [   0]  with_bmode
#
# 11 directories, 0 files
# /mnt/buckets/liulab/csx_experiments/varying_parameters/defaults,single_cell_true [error opening dir]
#
# 0 directories, 0 files

# %%
experiments = os.listdir(os.path.join("/mnt/buckets", experiments_root))
experiments
# Out:
# ['defaults',
#  'refsample_from_defaults',
#  'refsample_from_defaults,single_cell_true',
#  'refsample_from_defaults,with_bmode',
#  'refsample_from_webjob4',
#  'refsample_from_webjob4,with_bmode',
#  'sigmat_from_defaults',
#  'sigmat_from_defaults,with_bmode',
#  'sigmat_from_webjob4',
#  'sigmat_from_webjob4,with_bmode',
#  'with_bmode']

# %%
def load_csx_results(experiment_uri):
    try:
        uri = os.path.join(experiment_uri, "CIBERSORTx_Results.txt")
        df = pd.read_csv(uri, sep="\t", index_col=0)
    except:
        uri = os.path.join(experiment_uri, "CIBERSORTx_Adjusted.txt")
        df = pd.read_csv(uri, sep="\t", index_col=0)
    df = df.iloc[:, :-3]  # ignore last three columns, which are test statistics
    df.rename(columns=weird_to_nice, inplace=True)
    df.rename_axis(columns="cell_type", index="sample_id", inplace=True)
    return df.stack()

# %%
preds = dict()
# preds["derek"] = results_derek
# preds["me"] = results_docker
for experiment in experiments:
    try:
        experiment_uri = os.path.join("gs://", experiments_root, experiment)
        preds[experiment] = load_csx_results(experiment_uri)
    except FileNotFoundError:
        print("no results for", experiment, experiment_uri)

df_preds = pd.concat(preds, names=["experiment"], axis=0).rename("csx_fraction")

# df_preds = df_preds.unstack("experiment")

df_preds
# Out:
# experiment  sample_id  cell_type
# defaults    53         Malignant      0.046178
#                        Endothelial    0.027261
#                        CAF            0.058420
#                        T CD8          0.286861
#                        NK             0.164019
#                                         ...
# with_bmode  94         T CD8          0.003151
#                        NK             0.017730
#                        Macrophage     0.037556
#                        T CD4          0.468256
#                        B              0.291373
# Name: csx_fraction, Length: 1672, dtype: float64

# %%
truth = pd.read_csv(
    "gs://liulab/csx_example_files/groundtruth_Melanoma_Tirosh_et_al_SuppFig3b-d.txt",
    sep="\t",
    index_col=0,
)
truth.rename_axis(columns="cell_type", index="sample_id", inplace=True)
truth.rename(columns=weird_to_nice, inplace=True)
truth = truth.stack().to_frame(name="true_fraction")
truth
# Out:
#                        true_fraction
# sample_id cell_type
# 53        Malignant           0.1280
#           Endothelial         0.0880
#           CAF                 0.0320
#           T CD8               0.2000
#           NK                  0.0800
# ...                              ...
# 94        T CD8               0.2025
#           NK                  0.0041
#           Macrophage          0.0083
#           T CD4               0.3306
#           B                   0.2686
#
# [152 rows x 1 columns]

# %%
truth.join(df_preds.unstack("experiment"), how="left").corr().sort_values(
    by="true_fraction", ascending=False
)
# Out:
#                                           true_fraction  defaults  \
# true_fraction                                  1.000000  0.940378
# refsample_from_webjob4                         0.941592  0.990750
# sigmat_from_webjob4                            0.941592  0.990750
# refsample_from_defaults,with_bmode             0.940901  0.995794
# sigmat_from_defaults,with_bmode                0.940901  0.995794
# with_bmode                                     0.940901  0.995794
# defaults                                       0.940378  1.000000
# refsample_from_defaults                        0.940378  1.000000
# refsample_from_defaults,single_cell_true       0.940378  1.000000
# sigmat_from_defaults                           0.940378  1.000000
# refsample_from_webjob4,with_bmode              0.938370  0.986880
# sigmat_from_webjob4,with_bmode                 0.938370  0.986880
#
#                                           refsample_from_defaults  \
# true_fraction                                            0.940378
# refsample_from_webjob4                                   0.990750
# sigmat_from_webjob4                                      0.990750
# refsample_from_defaults,with_bmode                       0.995794
# sigmat_from_defaults,with_bmode                          0.995794
# with_bmode                                               0.995794
# defaults                                                 1.000000
# refsample_from_defaults                                  1.000000
# refsample_from_defaults,single_cell_true                 1.000000
# sigmat_from_defaults                                     1.000000
# refsample_from_webjob4,with_bmode                        0.986880
# sigmat_from_webjob4,with_bmode                           0.986880
#
#                                           refsample_from_defaults,single_cell_true  \
# true_fraction                                                             0.940378
# refsample_from_webjob4                                                    0.990750
# sigmat_from_webjob4                                                       0.990750
# refsample_from_defaults,with_bmode                                        0.995794
# sigmat_from_defaults,with_bmode                                           0.995794
# with_bmode                                                                0.995794
# defaults                                                                  1.000000
# refsample_from_defaults                                                   1.000000
# refsample_from_defaults,single_cell_true                                  1.000000
# sigmat_from_defaults                                                      1.000000
# refsample_from_webjob4,with_bmode                                         0.986880
# sigmat_from_webjob4,with_bmode                                            0.986880
#
#                                           refsample_from_defaults,with_bmode  \
# true_fraction                                                       0.940901
# refsample_from_webjob4                                              0.991459
# sigmat_from_webjob4                                                 0.991459
# refsample_from_defaults,with_bmode                                  1.000000
# sigmat_from_defaults,with_bmode                                     1.000000
# with_bmode                                                          1.000000
# defaults                                                            0.995794
# refsample_from_defaults                                             0.995794
# refsample_from_defaults,single_cell_true                            0.995794
# sigmat_from_defaults                                                0.995794
# refsample_from_webjob4,with_bmode                                   0.993899
# sigmat_from_webjob4,with_bmode                                      0.993899
#
#                                           refsample_from_webjob4  \
# true_fraction                                           0.941592
# refsample_from_webjob4                                  1.000000
# sigmat_from_webjob4                                     1.000000
# refsample_from_defaults,with_bmode                      0.991459
# sigmat_from_defaults,with_bmode                         0.991459
# with_bmode                                              0.991459
# defaults                                                0.990750
# refsample_from_defaults                                 0.990750
# refsample_from_defaults,single_cell_true                0.990750
# sigmat_from_defaults                                    0.990750
# refsample_from_webjob4,with_bmode                       0.995349
# sigmat_from_webjob4,with_bmode                          0.995349
#
#                                           refsample_from_webjob4,with_bmode  \
# true_fraction                                                      0.938370
# refsample_from_webjob4                                             0.995349
# sigmat_from_webjob4                                                0.995349
# refsample_from_defaults,with_bmode                                 0.993899
# sigmat_from_defaults,with_bmode                                    0.993899
# with_bmode                                                         0.993899
# defaults                                                           0.986880
# refsample_from_defaults                                            0.986880
# refsample_from_defaults,single_cell_true                           0.986880
# sigmat_from_defaults                                               0.986880
# refsample_from_webjob4,with_bmode                                  1.000000
# sigmat_from_webjob4,with_bmode                                     1.000000
#
#                                           sigmat_from_defaults  \
# true_fraction                                         0.940378
# refsample_from_webjob4                                0.990750
# sigmat_from_webjob4                                   0.990750
# refsample_from_defaults,with_bmode                    0.995794
# sigmat_from_defaults,with_bmode                       0.995794
# with_bmode                                            0.995794
# defaults                                              1.000000
# refsample_from_defaults                               1.000000
# refsample_from_defaults,single_cell_true              1.000000
# sigmat_from_defaults                                  1.000000
# refsample_from_webjob4,with_bmode                     0.986880
# sigmat_from_webjob4,with_bmode                        0.986880
#
#                                           sigmat_from_defaults,with_bmode  \
# true_fraction                                                    0.940901
# refsample_from_webjob4                                           0.991459
# sigmat_from_webjob4                                              0.991459
# refsample_from_defaults,with_bmode                               1.000000
# sigmat_from_defaults,with_bmode                                  1.000000
# with_bmode                                                       1.000000
# defaults                                                         0.995794
# refsample_from_defaults                                          0.995794
# refsample_from_defaults,single_cell_true                         0.995794
# sigmat_from_defaults                                             0.995794
# refsample_from_webjob4,with_bmode                                0.993899
# sigmat_from_webjob4,with_bmode                                   0.993899
#
#                                           sigmat_from_webjob4  \
# true_fraction                                        0.941592
# refsample_from_webjob4                               1.000000
# sigmat_from_webjob4                                  1.000000
# refsample_from_defaults,with_bmode                   0.991459
# sigmat_from_defaults,with_bmode                      0.991459
# with_bmode                                           0.991459
# defaults                                             0.990750
# refsample_from_defaults                              0.990750
# refsample_from_defaults,single_cell_true             0.990750
# sigmat_from_defaults                                 0.990750
# refsample_from_webjob4,with_bmode                    0.995349
# sigmat_from_webjob4,with_bmode                       0.995349
#
#                                           sigmat_from_webjob4,with_bmode  \
# true_fraction                                                   0.938370
# refsample_from_webjob4                                          0.995349
# sigmat_from_webjob4                                             0.995349
# refsample_from_defaults,with_bmode                              0.993899
# sigmat_from_defaults,with_bmode                                 0.993899
# with_bmode                                                      0.993899
# defaults                                                        0.986880
# refsample_from_defaults                                         0.986880
# refsample_from_defaults,single_cell_true                        0.986880
# sigmat_from_defaults                                            0.986880
# refsample_from_webjob4,with_bmode                               1.000000
# sigmat_from_webjob4,with_bmode                                  1.000000
#
#                                           with_bmode
# true_fraction                               0.940901
# refsample_from_webjob4                      0.991459
# sigmat_from_webjob4                         0.991459
# refsample_from_defaults,with_bmode          1.000000
# sigmat_from_defaults,with_bmode             1.000000
# with_bmode                                  1.000000
# defaults                                    0.995794
# refsample_from_defaults                     0.995794
# refsample_from_defaults,single_cell_true    0.995794
# sigmat_from_defaults                        0.995794
# refsample_from_webjob4,with_bmode           0.993899
# sigmat_from_webjob4,with_bmode              0.993899

# %%
x = df_preds.loc[["defaults", "sigmat_from_webjob4"]]
_ = (
    truth.join(x.unstack("experiment"), how="left")
    .corr()
    .sort_values(by="true_fraction", ascending=False)
)
_[["true_fraction"]]
# Out:
#                      true_fraction
# true_fraction             1.000000
# sigmat_from_webjob4       0.941592
# defaults                  0.940378

# %%
validation_set = [
    x not in (80, 88) for x in df_preds.index.get_level_values("sample_id")
]

# %%
_ = truth.join(
    df_preds.loc[:, validation_set, :].unstack("experiment"), how="left"
).corr()
_ = _[["true_fraction", "sigmat_from_webjob4", "defaults"]].loc[["true_fraction"]]
_["diff"] = _["defaults"] - _["sigmat_from_webjob4"]
_.columns = ["true_fraction", "web app", "docker", "(docker minus web app)"]
_
# Out:
#                true_fraction   web app    docker  (docker minus web app)
# true_fraction            1.0  0.939651  0.938371               -0.001281

# %%
_ = truth.join(
    df_preds.loc[:, validation_set, :].unstack("experiment"), how="left"
).corr()
_ = _[["true_fraction", "defaults", "with_bmode"]].loc[["true_fraction"]]
_["diff"] = _["with_bmode"] - _["defaults"]
_.columns = ["true_fraction", "normal", "w/ b-mode", "(normal minus w/ b-mode)"]
_
# Out:
#                true_fraction    normal  w/ b-mode  (normal minus w/ b-mode)
# true_fraction            1.0  0.938371   0.938945                  0.000574

# %%
_ = (
    truth.join(df_preds.loc[:, validation_set, :].unstack("experiment"), how="left")
    .groupby(level="cell_type")
    .corr()
    .stack()
    .loc[:, "true_fraction", ["true_fraction", "sigmat_from_webjob4", "defaults"]]
    .unstack()
    .sort_values(by="defaults", ascending=False)
)
_["diff"] = _["defaults"] - _["sigmat_from_webjob4"]
_.columns = ["true_fraction", "web app", "docker", "(docker minus web app)"]
_
# Out:
#                            true_fraction   web app    docker  \
# cell_type
# B           true_fraction            1.0  0.979727  0.979578
# Macrophage  true_fraction            1.0  0.947757  0.960535
# Malignant   true_fraction            1.0  0.956962  0.955860
# T CD4       true_fraction            1.0  0.942202  0.936408
# T CD8       true_fraction            1.0  0.897413  0.896265
# NK          true_fraction            1.0  0.895197  0.886451
# CAF         true_fraction            1.0  0.856806  0.845197
# Endothelial true_fraction            1.0  0.822015  0.813831
#
#                            (docker minus web app)
# cell_type
# B           true_fraction               -0.000149
# Macrophage  true_fraction                0.012779
# Malignant   true_fraction               -0.001102
# T CD4       true_fraction               -0.005794
# T CD8       true_fraction               -0.001148
# NK          true_fraction               -0.008747
# CAF         true_fraction               -0.011609
# Endothelial true_fraction               -0.008184

# %%
truth.join(
    df_preds.loc[:, validation_set, :].unstack("experiment")[["with_bmode"]], how="left"
).groupby(level="cell_type").corr().stack().loc[
    :, "true_fraction", "with_bmode"
].sort_values(
    ascending=False
)
# Out:
# cell_type
# B              0.979903
# Malignant      0.955684
# Macrophage     0.948048
# T CD4          0.937925
# T CD8          0.890556
# NK             0.883886
# CAF            0.863670
# Endothelial    0.861230
# dtype: float64

# %%
import plotly.io

plotly.io.renderers.default = "jupyterlab+png"

import plotly.express as px
import plotly.graph_objects as go

# %%
fig = px.bar(
    truth,
    x=truth.index.astype(str),
    y=truth.columns,
    title="True fractions of each mixture",
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-c3c95b697ed1> in <module>
#       1 fig = px.bar(
#       2     truth,
# ----> 3     x=truth.index.astype(str),
#       4     y=truth.columns,
#       5     title="True fractions of each mixture"
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/multi.py in astype(self, dtype, copy)
#    3771         elif not is_object_dtype(dtype):
#    3772             raise TypeError(
# -> 3773                 "Setting a MultiIndex dtype to anything other than object "
#    3774                 "is not supported"
#    3775             )
#
# TypeError: Setting a MultiIndex dtype to anything other than object is not supported
