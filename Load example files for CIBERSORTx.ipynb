# %%
import pandas as pd

# %%
import inspect

default_args = inspect.getfullargspec(pd.read_csv).args
sep_index = default_args.index("sep")
default_arg_values = list(pd.read_csv.__defaults__)
default_arg_values[sep_index] = '\t'
pd.read_csv.__defaults__ = tuple(default_arg_values)

# %%
pd.read_csv(
    "/home/jupyter/gcsfuse-babasonicos/csx_example_files/Expression_datasets/Fig2a-NSCLC_PBMCs_scRNAseq_matrix.txt",
    index_col="gene"
)
# Out:
#                CD8 T cells  CD8 T cells.1  CD8 T cells.2  CD14+ Monocytes  \
# gene
# RP11.34P13.7           0.0            0.0            0.0              0.0
# AL627309.1             0.0            0.0            0.0              0.0
# AP006222.2             0.0            0.0            0.0              0.0
# RP4.669L17.10          0.0            0.0            0.0              0.0
# RP5.857K21.3           0.0            0.0            0.0              0.0
# ...                    ...            ...            ...              ...
# AC011841.1             0.0            0.0            0.0              0.0
# AL354822.1             0.0            0.0            0.0              0.0
# KIR2DL2                0.0            0.0            0.0              0.0
# PNRC2.1                0.0            0.0            0.0              0.0
# SRSF10.1               0.0            0.0            0.0              0.0
#
#                CD14+ Monocytes.1  CD4 T cells  CD8 T cells.3  \
# gene
# ...
