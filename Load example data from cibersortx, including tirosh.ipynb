# %%
import glob

import pandas as pd

# %%
# mount google bucket
# !mkdir -p ~/mnt/liulab
# !fusermount -u ~/mnt/liulab
# !gcsfuse --implicit-dirs liulab ~/mnt/liulab
# Out:
# 2021/07/07 16:53:49.262892 Using mount point: /home/jupyter/mnt/liulab
# 2021/07/07 16:53:49.271614 Opening GCS connection...
# 2021/07/07 16:53:49.506140 Mounting file system "liulab"...
# 2021/07/07 16:53:49.509171 File system has been successfully mounted.

# %%
for fpath in glob.glob("/home/jupyter/mnt/liulab/csx_example_files/**/*", recursive=True):
#     if "sig" in fpath.lower():
    print(fpath)
# Out:
# /home/jupyter/mnt/liulab/csx_example_files/Expression_datasets
# /home/jupyter/mnt/liulab/csx_example_files/Fig2b_ground_truth_whole_blood.txt
# /home/jupyter/mnt/liulab/csx_example_files/LM22.txt
# /home/jupyter/mnt/liulab/csx_example_files/Single_Cell_RNA-Seq_Melanoma_SuppFig_3b-d
# /home/jupyter/mnt/liulab/csx_example_files/groundtruth_HNSCC_Puram_et_al_Fig2cd.txt
# /home/jupyter/mnt/liulab/csx_example_files/groundtruth_Melanoma_Tirosh_et_al_SuppFig3b-d.txt
# /home/jupyter/mnt/liulab/csx_example_files/Expression_datasets/Fig2a-NSCLC_PBMCs_scRNAseq_matrix.txt
# /home/jupyter/mnt/liulab/csx_example_files/Expression_datasets/Fig2b-WholeBlood_RNAseq.txt
# /home/jupyter/mnt/liulab/csx_example_files/Expression_datasets/Fig2b_ground_truth_whole_blood.txt
# /home/jupyter/mnt/liulab/csx_example_files/Expression_datasets/Fig3b-f-FL-arrays-groundtruth.RMA.txt
# /home/jupyter/mnt/liulab/csx_example_files/Expression_datasets/Fig3b-f-FL-arrays-mixture.txt
# ...

# %%
for fpath in glob.glob("/home/jupyter/mnt/liulab/csx_example_files/**/*", recursive=True):
    if "Tirosh" in fpath:
        print(fpath)
# Out:
# /home/jupyter/mnt/liulab/csx_example_files/groundtruth_Melanoma_Tirosh_et_al_SuppFig3b-d.txt
# /home/jupyter/mnt/liulab/csx_example_files/Single_Cell_RNA-Seq_Melanoma_SuppFig_3b-d/mixture_melanoma_Tirosh_SuppFig_3b-d.txt
# /home/jupyter/mnt/liulab/csx_example_files/Single_Cell_RNA-Seq_Melanoma_SuppFig_3b-d/scRNA-Seq_reference_melanoma_Tirosh_SuppFig_3b-d.txt

# %%
pd.read_csv(
    "/home/jupyter/mnt/liulab/csx_example_files/groundtruth_Melanoma_Tirosh_et_al_SuppFig3b-d.txt",
    sep="\t",
    index_col="GeneSymbol"
)
# Out:
#             Malignant  Endothelial cells     CAF  T cells CD8  NK cells  \
# GeneSymbol
# 53             0.1280             0.0880  0.0320       0.2000    0.0800
# 58             0.0000             0.0000  0.0000       0.6508    0.0317
# 59             0.8710             0.0000  0.1129       0.0000    0.0000
# 60             0.0448             0.0000  0.0000       0.1940    0.0498
# 65             0.0755             0.0000  0.0000       0.4717    0.0000
# 67             0.0000             0.0000  0.0000       0.3059    0.0118
# 71             0.6835             0.0000  0.0000       0.1899    0.0000
# 72             0.0000             0.0000  0.0000       0.1634    0.0065
# 74             0.0000             0.0000  0.0000       0.6496    0.0073
# 75             0.0087             0.0000  0.0000       0.9417    0.0000
# 78             0.9756             0.0000  0.0081       0.0000    0.0000
# 79             0.5474             0.0023  0.0012       0.2795    0.0012
# ...

# %%
pd.read_csv(
    "/home/jupyter/mnt/liulab/csx_example_files/Single_Cell_RNA-Seq_Melanoma_SuppFig_3b-d/mixture_melanoma_Tirosh_SuppFig_3b-d.txt",
    sep="\t",
    index_col="GeneSymbol"
).sort_index()
# Out:
#                      53           58           59          60          65  \
# GeneSymbol
# A1BG          29.955799   135.560624   164.675951   42.050063   44.209272
# A1BG.AS1      76.750472   106.710946     0.000000   98.890379   70.428488
# A1CF           4.293035    10.703480     7.683243    5.171856    0.485967
# A2M         2509.057478    90.334429  1257.425330   80.917243  483.387704
# A2M.AS1      165.340434   627.675397     0.000000  119.285327  259.847730
# ...                 ...          ...          ...         ...         ...
# ZYG11A       210.406776   406.413108    40.761214  191.982234   60.105820
# ZYG11B       137.569280   236.921709   188.989891  187.103564   51.005259
# ZYX         1101.767280  1315.280778   704.302282  781.906411  599.029492
# ZZEF1        123.405045   195.681735    54.269235  110.220029  240.136176
# ZZZ3         246.766559   456.159109   172.469766  517.498093  195.924683
#
# ...

# %%
pd.read_csv(
    "/home/jupyter/mnt/liulab/csx_example_files/Single_Cell_RNA-Seq_Melanoma_SuppFig_3b-d/scRNA-Seq_reference_melanoma_Tirosh_SuppFig_3b-d.txt",
    sep="\t",
    index_col="Gene"
).sort_index()
# Out:
#           Malignant  Malignant.1  Malignant.2  Malignant.3  Malignant.4  \
# Gene
# A1BG       0.000000     1.870098     1.489058     0.000000     1.885057
# A1BG.AS1   0.000000     0.000000     0.000000     0.000000     0.000000
# A1CF       0.057000     0.112997     1.901100     0.000000     0.000000
# A2M        7.211809     8.906669     3.825907     0.000000    15.962771
# A2M.AS1   11.109774     0.000000     0.000000     0.000000     0.000000
# ...             ...          ...          ...          ...          ...
# ZYG11A     0.414998     1.010982     0.421999     0.419999     0.708002
# ZYG11B     0.152998     0.727996     0.192997     0.126002     0.267003
# ZYX        0.000000     0.000000     0.000000     0.000000     0.000000
# ZZEF1      0.802001     0.921003     0.000000     0.000000     0.000000
# ZZZ3       9.384069    20.191297    19.442504     2.631083     0.000000
#
#           Malignant.5  Malignant.6  Malignant.7  Malignant.8  Malignant.9  \
# Gene
# ...
