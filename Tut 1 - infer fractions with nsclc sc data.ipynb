# %% [markdown]
# # tut 1
#
# NSCLC PBMCs Single Cell RNA-Seq (Fig. 2a,b):
# * This example builds a signature matrix from single cell RNA sequencing data from NSCLC PBMCs and enumerates the proportions of the different cell types in a RNA-seq dataset profiled from whole blood using S-mode batch correction.

# %% [markdown]
# # example 1: generate signature matrix

# %% [markdown]
# ### NSCLC PBMCs Single Cell RNA-Seq (Fig. 2a,b):
#
# This example builds a signature matrix from single cell RNA sequencing data from NSCLC PBMCs and enumerates the proportions of the different cell types in a RNA-seq dataset profiled from whole blood using S-mode batch correction.
#
# ```
# docker run \
#     -v absolute/path/to/input/dir:/src/data \
#     -v absolute/path/to/output/dir:/src/outdir \
#     cibersortx/fractions \
#     --username email_address_registered_on_CIBERSORTx_website \
#     --token token_obtained_from_CIBERSORTx_website \
#     --single_cell TRUE \
#     --refsample Fig2ab-NSCLC_PBMCs_scRNAseq_refsample.txt \
#     --mixture Fig2b-WholeBlood_RNAseq.txt \
#     --fraction 0 \
#     --rmbatchSmode TRUE
# ```

# %% [markdown]
# ## set up some stuff

# %%
import logging

# %%
logging.basicConfig()

# %% [markdown]
# ### download data

# %%
# !./scripts/download_csx_example_data.sh

# %% [markdown]
# ### read data into dataframes

# %%
import pandas as pd

logging.getLogger('pandas').setLevel('DEBUG')

# %%
path = (
    "/mnt/buckets/liulab/csx_example_files/Fig2ab-NSCLC_PBMCs/"
    "Fig2ab-NSCLC_PBMCs_scRNAseq_refsample.txt"
)

nsclc_pbmc_sc = pd.read_csv(
    path,
    sep='\t',
    index_col=0
)

nsclc_pbmc_sc
# Out:
#                T cells CD8  T cells CD8.1  T cells CD8.2  Monocytes  \
# gene
# RP11.34P13.7           0.0            0.0            0.0        0.0
# AL627309.1             0.0            0.0            0.0        0.0
# AP006222.2             0.0            0.0            0.0        0.0
# RP4.669L17.10          0.0            0.0            0.0        0.0
# RP5.857K21.3           0.0            0.0            0.0        0.0
# ...                    ...            ...            ...        ...
# AC011841.1             0.0            0.0            0.0        0.0
# AL354822.1             0.0            0.0            0.0        0.0
# KIR2DL2                0.0            0.0            0.0        0.0
# PNRC2.1                0.0            0.0            0.0        0.0
# SRSF10.1               0.0            0.0            0.0        0.0
#
#                Monocytes.1  T cells CD4  T cells CD8.3  Monocytes.2  \
# gene
# RP11.34P13.7           0.0          0.0        0.00000          0.0
# AL627309.1             0.0          0.0        0.00000          0.0
# AP006222.2             0.0          0.0      216.59086          0.0
# RP4.669L17.10          0.0          0.0        0.00000          0.0
# RP5.857K21.3           0.0          0.0        0.00000          0.0
# ...                    ...          ...            ...          ...
# AC011841.1             0.0          0.0        0.00000          0.0
# AL354822.1             0.0          0.0        0.00000          0.0
# KIR2DL2                0.0          0.0        0.00000          0.0
# PNRC2.1                0.0          0.0        0.00000          0.0
# SRSF10.1               0.0          0.0        0.00000          0.0
#
#                Monocytes.3  Monocytes.4  ...  T cells CD8.233  \
# gene                                     ...
# RP11.34P13.7           0.0          0.0  ...              0.0
# AL627309.1             0.0          0.0  ...              0.0
# AP006222.2             0.0          0.0  ...              0.0
# RP4.669L17.10          0.0          0.0  ...              0.0
# RP5.857K21.3           0.0          0.0  ...              0.0
# ...                    ...          ...  ...              ...
# AC011841.1             0.0          0.0  ...              0.0
# AL354822.1             0.0          0.0  ...              0.0
# KIR2DL2                0.0          0.0  ...              0.0
# PNRC2.1                0.0          0.0  ...              0.0
# SRSF10.1               0.0          0.0  ...              0.0
#
#                T cells CD8.234  NKT cells.80  Monocytes.454  Monocytes.455  \
# gene
# RP11.34P13.7          0.000000           0.0            0.0            0.0
# AL627309.1            0.000000           0.0            0.0            0.0
# AP006222.2            0.000000           0.0            0.0            0.0
# RP4.669L17.10         0.000000           0.0            0.0            0.0
# RP5.857K21.3          0.000000           0.0            0.0            0.0
# ...                        ...           ...            ...            ...
# AC011841.1            0.000000           0.0            0.0            0.0
# AL354822.1            0.000000           0.0            0.0            0.0
# KIR2DL2               0.000000           0.0            0.0            0.0
# PNRC2.1               0.000000           0.0            0.0            0.0
# SRSF10.1            233.208955           0.0            0.0            0.0
#
#                Monocytes.456  Monocytes.457  NKT cells.81  T cells CD8.235  \
# gene
# RP11.34P13.7             0.0            0.0           0.0              0.0
# AL627309.1               0.0            0.0           0.0              0.0
# AP006222.2               0.0            0.0           0.0              0.0
# RP4.669L17.10            0.0            0.0           0.0              0.0
# RP5.857K21.3             0.0            0.0           0.0              0.0
# ...                      ...            ...           ...              ...
# AC011841.1               0.0            0.0           0.0              0.0
# AL354822.1               0.0            0.0           0.0              0.0
# KIR2DL2                  0.0            0.0           0.0              0.0
# PNRC2.1                  0.0            0.0           0.0              0.0
# SRSF10.1                 0.0            0.0           0.0              0.0
#
#                Monocytes.458
# gene
# RP11.34P13.7             0.0
# AL627309.1               0.0
# AP006222.2               0.0
# RP4.669L17.10            0.0
# RP5.857K21.3             0.0
# ...                      ...
# AC011841.1               0.0
# AL354822.1               0.0
# KIR2DL2                  0.0
# PNRC2.1                  0.0
# SRSF10.1                 0.0
#
# [16476 rows x 1054 columns]

# %%
nsclc_pbmc_sc.sum(axis=0).sort_values()
# Out:
# T cells CD4.127    1000000.0
# Monocytes.175      1000000.0
# Monocytes.295      1000000.0
# T cells CD4.82     1000000.0
# T cells CD8.6      1000000.0
#                      ...
# Monocytes.319      1000000.0
# Monocytes.205      1000000.0
# T cells CD8.81     1000000.0
# Monocytes.81       1000000.0
# Monocytes.230      1000000.0
# Length: 1054, dtype: float64

# %%
path = (
    "/mnt/buckets/liulab/csx_example_files/Fig2ab-NSCLC_PBMCs/"
    "Fig2b-WholeBlood_RNAseq.txt"
)

nsclc_wholeblood_mixtures = pd.read_csv(
    path,
    sep='\t',
    index_col=0
)

nsclc_wholeblood_mixtures
# Out:
#            W070517001156  W070517001157  W070517001159  W070517001160  \
# GeneSym
# 5_8S_rRNA       0.000000       0.000000       0.000000       0.000000
# 5S_rRNA         0.000000       0.000000       0.000000       0.000000
# 7SK             0.000000       0.000000       0.000000       0.000000
# A1BG            1.524589       1.198209       2.281101       2.510963
# A1BG-AS1        0.210020       0.263073       0.410865       0.571484
# ...                  ...            ...            ...            ...
# ZYG11B         18.753000      10.084024       8.159590      12.489620
# ZYX           200.613353     140.107566     144.816461     134.412477
# ZYXP1           0.000000       0.000000       0.000000       0.000000
# ZZEF1          76.731847      61.515861      51.289958      80.723373
# ZZZ3            5.800347       4.778370       2.450307       6.514290
#
#            W070517001161  W070517001162  W070517102034  W070517102035  \
# GeneSym
# 5_8S_rRNA       0.000000       0.000000       0.000000       0.000000
# 5S_rRNA         0.000000       0.000000       0.000000       2.304710
# 7SK             0.000000       0.000000       0.000000       0.000000
# A1BG            1.752686       3.467098       2.523853       1.634724
# A1BG-AS1        0.139725       0.142219       0.348219       0.294046
# ...                  ...            ...            ...            ...
# ZYG11B          5.222887       6.192270       7.825120      12.366960
# ZYX            81.341464     107.785758      62.656594     265.309460
# ZYXP1           0.000000       0.000000       0.000000       0.000000
# ZZEF1          48.363048      44.139845      51.296040      63.324805
# ZZZ3            3.591229       6.402304       9.125066       6.316513
#
#            W070517102036  W070517102037  W070517102038  W070517102051
# GeneSym
# 5_8S_rRNA       0.000000       0.000000       0.000000       0.000000
# 5S_rRNA         0.000000       0.000000       0.752697       0.000000
# 7SK             0.000000       0.181943       0.000000       0.000000
# A1BG            2.687471       3.385051       2.195180       1.912779
# A1BG-AS1        0.732450       0.595088       0.424970       0.272239
# ...                  ...            ...            ...            ...
# ZYG11B          7.205970       7.896432       9.496550       8.637130
# ZYX            88.768774      94.147450     194.531694     127.203111
# ZYXP1           0.000000       0.000000       0.000000       0.000000
# ZZEF1          40.328860      49.242034      73.869547      62.659012
# ZZZ3            6.992138       8.938681       5.774578       5.538113
#
# [58581 rows x 12 columns]

# %% [markdown]
# ## run csx with docker

# %% [markdown]
# ```
# docker run \
#     -v absolute/path/to/input/dir:/src/data \
#     -v absolute/path/to/output/dir:/src/outdir \
#     cibersortx/fractions \
#     --username email_address_registered_on_CIBERSORTx_website \
#     --token token_obtained_from_CIBERSORTx_website \
#     --single_cell TRUE \
#     --refsample Fig2ab-NSCLC_PBMCs_scRNAseq_refsample.txt \
#     --mixture Fig2b-WholeBlood_RNAseq.txt \
#     --fraction 0 \
#     --rmbatchSmode TRUE
#
# ```

# %%
# !ls -l /mnt/buckets/liulab/csx_example_files/Fig2ab-NSCLC_PBMCs
# Out:
# total 57864
# -rw-r--r-- 1 jupyter jupyter 54711251 Jul 12  2018 Fig2ab-NSCLC_PBMCs_scRNAseq_refsample.txt
# -rw-r--r-- 1 jupyter jupyter   190077 Jul 12  2018 Fig2ab-NSCLC_PBMCs_scRNAseq_sigmatrix.txt
# -rw-r--r-- 1 jupyter jupyter  4350725 Jul 12  2018 Fig2b-WholeBlood_RNAseq.txt

# %%
# !./scripts/run_csx_fractions.sh
# Out:
# setting up CIBERSORTx in directory:
# /mnt/buckets/liulab/csx-runs/20210714_165603
# /mnt/buckets/liulab/csx-runs/20210714_165603
# ├── [   0]  in
# │   ├── [4.1M]  mymixture.txt
# │   └── [ 52M]  myrefsample.txt
# └── [   0]  out
#
# 2 directories, 2 files
# >Running CIBERSORTxFractions...
# >[Options] username: lyronctk@stanford.edu
# >[Options] token: dfeba2c8b9d61daebee5fa87026b8e56
# >[Options] single_cell: TRUE
# >[Options] refsample: myrefsample.txt
# >[Options] mixture: mymixture.txt
# >[Options] rmbatchSmode: TRUE
# >[Options] verbose: TRUE
# >Making reference sample file.
# >Making phenotype class file.
# >single_cell is set to TRUE, so quantile normalization is set to FALSE, and the default parameters for building the signature matrix have been set to the following values:
# 	- G.min <- 300
# 	- G.max <- 500
# 	- q.value <- 0.01
# >==========Signature Matrix Settings============
# >Pure samples file: /src/outdir//CIBERSORTx_myrefsample_inferred_refsample.txt
# >Phenotype classes file: /src/outdir//CIBERSORTx_myrefsample_inferred_phenoclasses.txt
# >Minimum number of DEGs to consider from each phenotype for signature matrix set to: 300
# >Maximum number of DEGs to consider from each phenotype for signature matrix set to: 500
# >Q-value for signature matrix construction set to: 0.01
# >Quantile normalization of input samples is disabled
# >===============================================
# >C++14
# >Loaded 30 columns and 16476 rows
# >=============Make Signature Matrix=============
# >Maximum condition number (kappa):999
# >19433 DEG expressed across 6 samples were identified
# >Group size: 375, Kappa: 7.28267299347319
# >Best kappa: 7.28267299347319
# >SVD UpperRightDiag: 16634
# >SVD LowerRightDiag: 2284.05
# >=============CIBERSORTx Settings===============
# >Mixture file: /src/data/mymixture.txt
# >Signature matrix file: /src/outdir//CIBERSORTx_myrefsample_inferred_phenoclasses.CIBERSORTx_myrefsample_inferred_refsample.bm.K999.txt
# >Enable verbose output
# >Do S-mode batch correction
# >==================CIBERSORTx===================
# >Adjusting mixtures with S-mode batch correction.
# >Running CIBERSORTx on unadjusted mixtures with S-mode adjusted signature matrix.
# >=============CIBERSORTx Settings===============
# >Mixture file: /src/data/mymixture.txt
# >Signature matrix file: /src/outdir//CIBERSORTx_sigmatrix_Adjusted.txt
# >Enable verbose output
# >==================CIBERSORTx===================
# column T cells CD8 Monocytes T cells CD4 NKT cells B cells NK cells P-value Correlation RMSE %Completed
# 1 0.131738 0.549439 0.179788 0.00966146 0.0906035 0.0387695 9999 8.33333
# 2 0.119294 0.37519 0.330122 0.0493449 0.084047 0.0420026 9999 16.6667
# 3 0.158007 0.500826 0.150915 0.0239061 0.1066 0.0597473 9999 25
# 4 0.110199 0.418301 0.323309 0.0141733 0.077929 0.0560881 9999 33.3333
# 5 0.261422 0.42206 0.142562 0.030552 0.0794438 0.0639601 9999 41.6667
# 6 0.186941 0.289434 0.302025 0.0374662 0.099633 0.0845007 9999 50
# 7 0.14799 0.282104 0.414396 0 0.109783 0.045727 9999 58.3333
# 8 0.143681 0.475186 0.232682 0.00196077 0.0914388 0.0550508 9999 66.6667
# 9 0.24087 0.374814 0.224117 0.00353872 0.105089 0.05157 9999 75
# 10 0.250058 0.222237 0.295157 0.0189672 0.158394 0.0551865 9999 83.3333
# 11 0.196184 0.35576 0.264637 0.00825106 0.119804 0.0553635 9999 91.6667
# 12 0.186759 0.466902 0.17281 0 0.0938207 0.0797075 9999 100
# /mnt/buckets/liulab/csx-runs/20210714_165603
# ├── [   0]  in
# │   ├── [4.1M]  mymixture.txt
# │   └── [ 52M]  myrefsample.txt
# └── [   0]  out
#     ├── [2.4K]  CIBERSORTx_Adjusted.txt
#     ├── [3.2M]  CIBERSORTx_Mixtures_Adjusted.txt
#     ├── [2.0M]  CIBERSORTx_cell_type_sourceGEP.txt
#     ├── [ 84K]  CIBERSORTx_myrefsample_inferred_phenoclasses.CIBERSORTx_myrefsample_inferred_refsample.bm.K999.pdf
#     ├── [228K]  CIBERSORTx_myrefsample_inferred_phenoclasses.CIBERSORTx_myrefsample_inferred_refsample.bm.K999.txt
#     ├── [ 421]  CIBERSORTx_myrefsample_inferred_phenoclasses.txt
#     ├── [9.6M]  CIBERSORTx_myrefsample_inferred_refsample.txt
#     └── [233K]  CIBERSORTx_sigmatrix_Adjusted.txt
#
# 2 directories, 10 files

# %%
path = (
    "/mnt/buckets/liulab/csx-runs/20210714_165603/out/"
    "CIBERSORTx_sigmatrix_Adjusted.txt"
)

learned_sigmatrix = pd.read_csv(
    path,
    sep='\t',
    index_col=0
)

# %%
learned_sigmatrix.sample(10)
# Out:
#             T cells CD8   Monocytes  T cells CD4    NKT cells     B cells  \
# GeneSymbol
# F13A1         31.582554  116.291470    16.543526    19.393538    0.000000
# GNLY         204.601176   89.981023   101.019920  1603.024312   18.236959
# IGSF6         10.614040  115.769768     6.293894    13.371633   46.869165
# PRRC2B        41.120586   22.222028    25.461029    18.329093   23.464044
# CD79B          0.000000   25.660625    43.955907     7.260332  820.412897
# SCML4         36.192520    3.996084    44.851980    56.727066   15.053210
# VPS13C        87.172807  111.992892    43.918278    63.700344    0.000000
# HMGCL         26.608174   12.364090    16.029836    25.671054   63.150202
# ZCCHC6        65.567998   91.804041    32.839599    38.819955   34.748406
# SDF2L1        14.309750    9.338532     4.656168    28.555987   11.328592
#
#                NK cells
# GeneSymbol
# F13A1         16.128564
# GNLY        2796.002095
# IGSF6         25.520371
# PRRC2B        17.333819
# CD79B         18.707355
# SCML4         34.545712
# VPS13C        32.793671
# HMGCL         36.013538
# ZCCHC6        47.654076
# SDF2L1        35.662218

# %%
path = (
    "/mnt/buckets/liulab/csx-runs/20210714_165603/in/"
    "mymixture.txt"
)

mixtures = pd.read_csv(
    path,
    sep='\t',
    index_col=0
)

# %%
mixtures
# Out:
#            W070517001156  W070517001157  W070517001159  W070517001160  \
# GeneSym
# 5_8S_rRNA       0.000000       0.000000       0.000000       0.000000
# 5S_rRNA         0.000000       0.000000       0.000000       0.000000
# 7SK             0.000000       0.000000       0.000000       0.000000
# A1BG            1.524589       1.198209       2.281101       2.510963
# A1BG-AS1        0.210020       0.263073       0.410865       0.571484
# ...                  ...            ...            ...            ...
# ZYG11B         18.753000      10.084024       8.159590      12.489620
# ZYX           200.613353     140.107566     144.816461     134.412477
# ZYXP1           0.000000       0.000000       0.000000       0.000000
# ZZEF1          76.731847      61.515861      51.289958      80.723373
# ZZZ3            5.800347       4.778370       2.450307       6.514290
#
#            W070517001161  W070517001162  W070517102034  W070517102035  \
# GeneSym
# 5_8S_rRNA       0.000000       0.000000       0.000000       0.000000
# 5S_rRNA         0.000000       0.000000       0.000000       2.304710
# 7SK             0.000000       0.000000       0.000000       0.000000
# A1BG            1.752686       3.467098       2.523853       1.634724
# A1BG-AS1        0.139725       0.142219       0.348219       0.294046
# ...                  ...            ...            ...            ...
# ZYG11B          5.222887       6.192270       7.825120      12.366960
# ZYX            81.341464     107.785758      62.656594     265.309460
# ZYXP1           0.000000       0.000000       0.000000       0.000000
# ZZEF1          48.363048      44.139845      51.296040      63.324805
# ZZZ3            3.591229       6.402304       9.125066       6.316513
#
#            W070517102036  W070517102037  W070517102038  W070517102051
# GeneSym
# 5_8S_rRNA       0.000000       0.000000       0.000000       0.000000
# 5S_rRNA         0.000000       0.000000       0.752697       0.000000
# 7SK             0.000000       0.181943       0.000000       0.000000
# A1BG            2.687471       3.385051       2.195180       1.912779
# A1BG-AS1        0.732450       0.595088       0.424970       0.272239
# ...                  ...            ...            ...            ...
# ZYG11B          7.205970       7.896432       9.496550       8.637130
# ZYX            88.768774      94.147450     194.531694     127.203111
# ZYXP1           0.000000       0.000000       0.000000       0.000000
# ZZEF1          40.328860      49.242034      73.869547      62.659012
# ZZZ3            6.992138       8.938681       5.774578       5.538113
#
# [58581 rows x 12 columns]

# %%
pd.merge(learned_sigmatrix, mixtures['W070517001156'], left_index=True, right_index=True)
# Out:
#          T cells CD8   Monocytes  T cells CD4  NKT cells    B cells  \
# A1BG        9.279932   19.968371     7.059486   5.317669   5.934505
# AATF       40.693993   27.234785    18.720587  74.402640  21.070055
# ABCF1      52.575306   20.556804    43.116876  43.514392  16.124892
# ABHD14A    13.013968    3.411371     5.650299  14.566843   0.000000
# ABHD2      31.165896  100.307776    20.938952  48.473854   0.000000
# ...              ...         ...          ...        ...        ...
# ZNF800     65.349101   24.597513    37.836547  73.230805  39.224281
# ZNF92      20.641427    5.142733    11.595737  12.037755  31.046507
# ZNRD1      20.728089   10.430958    15.253098  27.972517   0.000000
# ZRSR2      64.781923   34.281854    47.319957  34.485672  66.667349
# ZSWIM7     16.498761   20.560696    20.930302   7.915512  34.006648
#
#           NK cells  W070517001156
# A1BG     18.955470       1.524589
# AATF     52.783887      40.336661
# ABCF1    81.494719      40.893660
# ABHD14A   0.577246       0.824229
# ABHD2    30.596787     145.571646
# ...            ...            ...
# ZNF800   71.555645      52.661468
# ZNF92     7.320498       3.499944
# ZNRD1    22.661131       3.807222
# ZRSR2    65.680700      59.136600
# ZSWIM7    6.633428       6.511087
#
# [1759 rows x 7 columns]

# %% [markdown]
# # attempt inferring fractions myself with sigmatrix, mixture

# %%
import numpy

from sklearn.svm import NuSVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
np.set_printoptions(precision=6, suppress=True)

# %%
_combined_data = pd.merge(learned_sigmatrix, mixtures['W070517001156'], left_index=True, right_index=True)
y = _combined_data.values[:, -1]
X = _combined_data.values[:, :-1]
y.shape, X.shape
# Out:
# ((1759,), (1759, 6))

# %%
regr = make_pipeline(StandardScaler(), NuSVR(nu=0.5, kernel='linear'))
regr.fit(X, y)
_ = regr.named_steps['nusvr'].coef_
_ / np.sum(_)
# Out:
# array([[0.085325, 0.671353, 0.09712 , 0.015047, 0.077711, 0.053444]])

# %% [markdown]
# # check fractions inferred by csx

# %%
path = (
    "/mnt/buckets/liulab/csx-runs/20210714_165603/out/"
    "CIBERSORTx_Adjusted.txt"
)

inferred_fractions = pd.read_csv(
    path,
    sep='\t',
    index_col=0
)

inferred_fractions.loc['W070517001156'][['T cells CD8', 'Monocytes', 'T cells CD4', 'NKT cells', 'B cells',
       'NK cells']].values
# Out:
# array([0.131738, 0.549439, 0.179788, 0.009661, 0.090603, 0.038769])

# %% [markdown]
# # extra

# %%
pd.read_csv(
    "/mnt/buckets/liulab/csx_example_files/Fig2ab-NSCLC_PBMCs/Fig2ab-NSCLC_PBMCs_scRNAseq_sigmatrix.txt",
    sep='\t',
    index_col=0
)
# Out:
#          T cells CD8  Monocytes  T cells CD4   NKT cells  B cells    NK cells
# NAME
# A2M.AS1    42.389248   3.034278     8.406227   47.115313      1.0    1.000000
# AAK1      171.246018  53.947719   245.690249  189.969058      1.0  176.336120
# ABCA1       3.097667  14.269549     1.000000    1.000000      1.0    1.000000
# ABCA2      22.847189   2.331345     3.134736   21.462190      1.0   34.812778
# ABCA3       1.000000   1.653714     1.000000    8.154662      1.0   11.566915
# ...              ...        ...          ...         ...      ...         ...
# ZSWIM1      1.000000   1.461999     6.619884    1.000000      1.0    1.000000
# ZSWIM6     12.516047  33.538731     2.002665    6.003127      1.0    1.000000
# ZXDA        4.640282   1.000000     1.000000    1.000000      1.0    1.000000
# ZXDB        6.661040   1.751215     8.746464    1.000000      1.0    1.000000
# ZYG11B      1.915577  25.536210    13.103367    1.000000      1.0   22.055735
#
# [2498 rows x 6 columns]

# %%
pd.read_csv(
    "/mnt/buckets/liulab/csx_example_files/Fig2ab-NSCLC_PBMCs/Fig2b-WholeBlood_RNAseq.txt",
    sep='\t',
    index_col=0
)
# Out:
#            W070517001156  W070517001157  W070517001159  W070517001160  \
# GeneSym
# 5_8S_rRNA       0.000000       0.000000       0.000000       0.000000
# 5S_rRNA         0.000000       0.000000       0.000000       0.000000
# 7SK             0.000000       0.000000       0.000000       0.000000
# A1BG            1.524589       1.198209       2.281101       2.510963
# A1BG-AS1        0.210020       0.263073       0.410865       0.571484
# ...                  ...            ...            ...            ...
# ZYG11B         18.753000      10.084024       8.159590      12.489620
# ZYX           200.613353     140.107566     144.816461     134.412477
# ZYXP1           0.000000       0.000000       0.000000       0.000000
# ZZEF1          76.731847      61.515861      51.289958      80.723373
# ZZZ3            5.800347       4.778370       2.450307       6.514290
#
#            W070517001161  W070517001162  W070517102034  W070517102035  \
# GeneSym
# 5_8S_rRNA       0.000000       0.000000       0.000000       0.000000
# 5S_rRNA         0.000000       0.000000       0.000000       2.304710
# 7SK             0.000000       0.000000       0.000000       0.000000
# A1BG            1.752686       3.467098       2.523853       1.634724
# A1BG-AS1        0.139725       0.142219       0.348219       0.294046
# ...                  ...            ...            ...            ...
# ZYG11B          5.222887       6.192270       7.825120      12.366960
# ZYX            81.341464     107.785758      62.656594     265.309460
# ZYXP1           0.000000       0.000000       0.000000       0.000000
# ZZEF1          48.363048      44.139845      51.296040      63.324805
# ZZZ3            3.591229       6.402304       9.125066       6.316513
#
#            W070517102036  W070517102037  W070517102038  W070517102051
# GeneSym
# 5_8S_rRNA       0.000000       0.000000       0.000000       0.000000
# 5S_rRNA         0.000000       0.000000       0.752697       0.000000
# 7SK             0.000000       0.181943       0.000000       0.000000
# A1BG            2.687471       3.385051       2.195180       1.912779
# A1BG-AS1        0.732450       0.595088       0.424970       0.272239
# ...                  ...            ...            ...            ...
# ZYG11B          7.205970       7.896432       9.496550       8.637130
# ZYX            88.768774      94.147450     194.531694     127.203111
# ZYXP1           0.000000       0.000000       0.000000       0.000000
# ZZEF1          40.328860      49.242034      73.869547      62.659012
# ZZZ3            6.992138       8.938681       5.774578       5.538113
#
# [58581 rows x 12 columns]
